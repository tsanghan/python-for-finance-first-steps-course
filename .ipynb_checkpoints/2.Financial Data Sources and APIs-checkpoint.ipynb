# %% [markdown]
# # 1. Financial Data Sources and APIs
# ## Abdullah Karasan

# %% [markdown]
# At this point, I would like to introduce how we access the main financial and economics data as we are about to employ these data in financial modeling. One of the shortest way to access the data is to use `Application Program  Interface` or `API`.  Followings are some of the good reasons to use APIs:

# %% [markdown]
# * Downloading data directly from the websute takes time. I do not even talk about if we want to download large data set (>1 GB) into our local computer, it may turn to a torture.
# * We need a subset from a large dataset. Using APIs results in easy filtering
# * If we are running an analysis requiring repeated computation, then accessing it via APIs is a life-saver for us. Because, otherwise, as we can imagine, we should visit the related website everytime we need data.

# %% [markdown]
# ## 2.1. Yahoo Finance API

# %% [markdown]
# Yahoo finance allows users to access the stock quotes, up-to-date news, portfolio management resources, international market data and so on. In order to access this resource, we, first, will install the `yahoo-finance` package via `pip3`:

# %% [markdown]
#     pip3 install yfinance

# %% [markdown]
#  Once we install the `yfinance`, it is time to import the Pyhton package:

# %%
import yfinance as yf

# %% [markdown]
# In the following example, we will extract a couple of stock data. However, before applying the Python application, there are few thing to know. First of all, we need to specify the tickers' of the stocks. Ticker basically symbolizes the stock and instead of writing the full name of the stock, using ticker is more convenient.

# %% [markdown]
# In addition to that, datime is required because we are trying to access a data with time dimension. Start time and end time defines the time period in which we analyze the stock price. Finally, the time interval needs to be defined as we can prefer analyzing the stock price based on different time interval such as daily, weekly, monthly, or yearly.

# %% [markdown]
# Let's extract daily stock price of `Apple` between 01.01.2010-04.09.2020.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn')

# %%
stock = '^GSPC'
start = datetime.datetime(2010,1,1)
end = datetime.datetime(2020,4,9)
SP = yf.download(stock,start=start,end = end, interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %% [markdown]
# Now, we have the Apple stock price within specified period.

# %%
SP.head()
# Out:
#                Open     High      Low    Close  Adj Close      Volume
# Date
# 2009-12-31  1126.60  1127.64  1114.81  1115.10    1115.10  2076990000
# 2010-01-04  1116.56  1133.87  1116.56  1132.99    1132.99  3991400000
# 2010-01-05  1132.66  1136.63  1129.66  1136.52    1136.52  2491020000
# 2010-01-06  1135.71  1139.19  1133.95  1137.14    1137.14  4972660000
# 2010-01-07  1136.27  1142.46  1131.32  1141.69    1141.69  5270680000

# %% [markdown]
# As you notice, we have open, `high`, `low`, `close`, `adjusted close` prices and `volume` with date index. It does not make sense to work with all these data. So, we select closing price to move forward.

# %%
SP_close=SP.Close

# %% [markdown]
# Now, we have closing price of Apple.

# %%
plt.plot(SP_close)
plt.title('S&P-500 Prices')
plt.ylabel('$')
plt.xlabel('Date')
plt.show()

# %% [markdown]
# ## 2.2. Federal Reserve Economic Data (FRED)

# %% [markdown]
# Using `FRED` API, we are allowed to retrieve economic data from the `FRED` website hosted by the `Economic Research Division of the Federal Reserve Bank of St. Louis`.

# %% [markdown]
# In order to have your FRED API, please visit this [website](https://research.stlouisfed.org/docs/api/api_key.html) first and follow the necessary steps. Let's move on.

# %% [markdown]
# As always, first install the `fredapi` Python library. Then, import the `fredapi` as `Fred`.

# %%
pip3 install fredapi

# %%
from fredapi import Fred
fred = Fred(api_key='78b14ec6ba46f484b94db43694468bb1')

# %% [markdown]
# As we access very very large database, it is not possible to observe data simply by typing `.head()`. Instead, we need to search to locate which data we are looking for. I would like to retrive economic growth data but there is plenty versions of it. Of them, we choose the one that serves my purpose best. we use `growth` as keyword. We can try any keyword of your choice.

# %%
fred.search('interest')
# Out:
#                               id realtime_start realtime_end  \
# series id
# FEDFUNDS                FEDFUNDS     2020-07-29   2020-07-29
# DFF                          DFF     2020-07-29   2020-07-29
# BAMLH0A0HYM2        BAMLH0A0HYM2     2020-07-29   2020-07-29
# FF                            FF     2020-07-29   2020-07-29
# DGS10                      DGS10     2020-07-29   2020-07-29
# ...                          ...            ...          ...
# IR3TIB01ESQ156N  IR3TIB01ESQ156N     2020-07-29   2020-07-29
# IR3TIB01ESA156N  IR3TIB01ESA156N     2020-07-29   2020-07-29
# LVAIRLTLT01STQ    LVAIRLTLT01STQ     2020-07-29   2020-07-29
# LVAIRLTLT01STM    LVAIRLTLT01STM     2020-07-29   2020-07-29
# IR3TIB01CZA156N  IR3TIB01CZA156N     2020-07-29   2020-07-29
#
#                                                              title  \
# series id
# FEDFUNDS                              Effective Federal Funds Rate
# DFF                                   Effective Federal Funds Rate
# BAMLH0A0HYM2     ICE BofA US High Yield Index Option-Adjusted S...
# FF                                    Effective Federal Funds Rate
# DGS10                      10-Year Treasury Constant Maturity Rate
# ...                                                            ...
# IR3TIB01ESQ156N  3-Month or 90-day Rates and Yields: Interbank ...
# IR3TIB01ESA156N  3-Month or 90-day Rates and Yields: Interbank ...
# LVAIRLTLT01STQ   Interest Rates: Long-term government bond yiel...
# LVAIRLTLT01STM   Interest Rates: Long-term government bond yiel...
# IR3TIB01CZA156N  3-Month or 90-day Rates and Yields: Interbank ...
#
#                 observation_start observation_end                 frequency  \
# series id
# FEDFUNDS               1954-07-01      2020-06-01                   Monthly
# DFF                    1954-07-01      2020-07-27              Daily, 7-Day
# BAMLH0A0HYM2           1996-12-31      2020-07-27              Daily, Close
# FF                     1954-07-07      2020-07-22  Weekly, Ending Wednesday
# DGS10                  1962-01-02      2020-07-27                     Daily
# ...                           ...             ...                       ...
# IR3TIB01ESQ156N        1977-01-01      2020-04-01                 Quarterly
# IR3TIB01ESA156N        1977-01-01      2019-01-01                    Annual
# LVAIRLTLT01STQ         2001-01-01      2020-01-01                 Quarterly
# LVAIRLTLT01STM         2001-01-01      2020-05-01                   Monthly
# IR3TIB01CZA156N        1993-01-01      2019-01-01                    Annual
#
#                 frequency_short    units units_short      seasonal_adjustment  \
# series id
# FEDFUNDS                      M  Percent           %  Not Seasonally Adjusted
# DFF                           D  Percent           %  Not Seasonally Adjusted
# BAMLH0A0HYM2                  D  Percent           %  Not Seasonally Adjusted
# FF                            W  Percent           %  Not Seasonally Adjusted
# DGS10                         D  Percent           %  Not Seasonally Adjusted
# ...                         ...      ...         ...                      ...
# IR3TIB01ESQ156N               Q  Percent           %  Not Seasonally Adjusted
# IR3TIB01ESA156N               A  Percent           %  Not Seasonally Adjusted
# LVAIRLTLT01STQ                Q  Percent           %  Not Seasonally Adjusted
# LVAIRLTLT01STM                M  Percent           %  Not Seasonally Adjusted
# IR3TIB01CZA156N               A  Percent           %  Not Seasonally Adjusted
#
#                 seasonal_adjustment_short               last_updated  \
# series id
# FEDFUNDS                              NSA  2020-07-22 12:06:01-05:00
# DFF                                   NSA  2020-07-28 15:23:21-05:00
# BAMLH0A0HYM2                          NSA  2020-07-28 07:38:01-05:00
# FF                                    NSA  2020-07-23 15:23:31-05:00
# DGS10                                 NSA  2020-07-28 15:23:01-05:00
# ...                                   ...                        ...
# IR3TIB01ESQ156N                       NSA  2020-07-10 14:24:18-05:00
# IR3TIB01ESA156N                       NSA  2020-01-29 07:27:31-06:00
# LVAIRLTLT01STQ                        NSA  2020-05-14 17:13:06-05:00
# LVAIRLTLT01STM                        NSA  2020-07-10 14:26:27-05:00
# IR3TIB01CZA156N                       NSA  2020-01-29 07:38:42-06:00
#
#                 popularity                                              notes
# series id
# FEDFUNDS                97  Averages of daily figures.  The federal funds ...
# DFF                     83  The federal funds rate is the interest rate at...
# BAMLH0A0HYM2           100  The ICE BofA Option-Adjusted Spreads (OASs) ar...
# FF                      60  Averages of daily figures.  The federal funds ...
# DGS10                   96  For further information regarding treasury con...
# ...                    ...                                                ...
# IR3TIB01ESQ156N          3  OECD descriptor ID: IR3TIB01 OECD unit ID: ST ...
# IR3TIB01ESA156N          3  OECD descriptor ID: IR3TIB01 OECD unit ID: ST ...
# LVAIRLTLT01STQ           3  OECD descriptor ID: IRLTLT01 OECD unit ID: ST ...
# LVAIRLTLT01STM           3  OECD descriptor ID: IRLTLT01 OECD unit ID: ST ...
# IR3TIB01CZA156N          2  OECD descriptor ID: IR3TIB01 OECD unit ID: ST ...
#
# [1000 rows x 15 columns]

# %% [markdown]
# For instance, the data in the first row called 'FEDFUNDS', which is `Effective Federal Funds Rate`. Now, we filter this data. To do that, we type `fred.get_series('series id')`. `Series id` locates in the left-most part of the fred search result.

# %%
interest=fred.get_series('FEDFUNDS')

# %%
plt.plot(interest)
plt.title('Monthly Interest Rate %')
plt.ylabel('%')
plt.xlabel('Date')
plt.show()

# %% [markdown]
# ## 2.3. Quandl

# %% [markdown]
# Quandl is a source for financial, economic, and alternative datasets, which is used worldwide. The procedure that we need to follow to access the data is not very different from that of FRED. Thus, we need to first this [website](https://www.quandl.com/tools/api) and the bottom of the page you see `Sign Up` button. Once you click on it and follow the required steps, you have your Quandl API.

# %% [markdown]
# After having the API, we need to install the Python library for Quandl, which is `quandl`. Then, once we import `quandl`, we are ready to play with the data of our choice.

# %% [markdown]
# !pip install quandl

# %%
import quandl

# %% [markdown]
# We are ready to move on and we would like to retrieve `WTI Crude Oil Price`from US Department of Energy. Once we run the following code, we can observe what we get by `.head()`

# %%
oil=quandl.get("EIA/PET_RWTC_D", authtoken="sezjeVxkKghvxARoxQAo", start_date="2010-01-01", end_date="2020-01-01")

# %%
oil.head()
# Out:
#             Value
# Date
# 2010-01-04  81.52
# 2010-01-05  81.74
# 2010-01-06  83.12
# 2010-01-07  82.60
# 2010-01-08  82.74

# %% [markdown]
# Here, we again choose close oil price and plot it.

# %%
plt.plot(oil)
plt.title('Crude Oil Price')
plt.ylabel('$')
plt.xlabel('Date')
plt.show()

# %% [markdown]
# ## 2.4. CRSP and Compustat

# %% [markdown]
# Center for `Research in Security Prices` (CRSP) hosts wide range of financial data starting from December 1963. Here are some data that can be found in CRSP:

# %% [markdown]
# * US Stock Databases
# * Historical Indexes
# * US Index History Files - Intraday
# * US Treasury Database
# * Survivor-Bias-Free US Mutual Funds
# * Cap-Based Portfolio Index

# %% [markdown]
# It sounds quite appealing, doesn't it? However, it is not freely available. Anyway, for those who has subscription, we briefly introduce a few steps about retreiving data from CRSP. To access CRSP, it is required to install `WRDS` (Wharton Research Data Service), which hosts CRSP along with many other database. Then, import the `wrds` library.

# %% [markdown]
#     !pip3 install wrds

# %%
import wrds

# %% [markdown]
# After installation, as it requires subscription, we need to type `user name` and `password` by connecting WRDS database. After this step, we are ready to extract the dataset we arelooking for.

# %%
db = wrds.Connection()
# Out:
# Enter your WRDS username [abdullah]:sduman
# Enter your password:········
# WRDS recommends setting up a .pgpass file.
# You can find more info here:
# https://www.postgresql.org/docs/9.5/static/libpq-pgpass.html.
# Loading library list...
# Done

# %%
bid_ask = db.raw_sql('select cusip,permno,date,bidlo,askhi from crsp.dsf LIMIT 100')

# %%
bid_ask
# Out:
#        cusip   permno        date      bidlo      askhi
# 0   92189F47  12744.0  2011-09-14  24.499599  24.580000
# 1   92189F47  12744.0  2011-09-15  24.430000  24.545000
# 2   92189F47  12744.0  2011-09-16  24.530001  24.629999
# 3   92189F47  12744.0  2011-09-19  24.280100  24.330000
# 4   92189F47  12744.0  2011-09-20  24.139999  24.280001
# ..       ...      ...         ...        ...        ...
# 95  92189F47  12744.0  2012-01-30  24.600000  24.650000
# 96  92189F47  12744.0  2012-01-31  24.709999  24.799999
# 97  92189F47  12744.0  2012-02-01  24.743999  24.743999
# 98  92189F47  12744.0  2012-02-02  24.825500  24.900000
# 99  92189F47  12744.0  2012-02-03  24.949900  24.950001
#
# [100 rows x 5 columns]

# %% [markdown]
# ## 2.5. World Bank Data

# %% [markdown]
# Eventually, I would like to introduce another database called `World Bank Database`, which is quite comprehensive and include many development indicators. It is free and open access to global development data and it is rather user-friendly. Let's get started to learn how to extract data from World Bank Database.

# %% [markdown]
# As usual, first we install the required Python package via `pip` and then import library `wbdata`

# %% [markdown]
#     pip3 install world_bank_data

# %%
import world_bank_data as wb

# %% [markdown]
# After import the world bank library, we access the list of databases by:

# %%
wb.get_sources()
# Out:
#    lastupdated                                               name code  \
# id
# 1   2019-10-23                                     Doing Business  DBS
# 2   2020-07-01                       World Development Indicators  WDI
# 3   2019-11-07                    Worldwide Governance Indicators  WGI
# 5   2016-03-21                  Subnational Malnutrition Database  SNM
# 6   2019-12-02                      International Debt Statistics  IDS
# ..         ...                                                ...  ...
# 76  2018-01-22    Remittance Prices Worldwide (Sending Countries)  RWS
# 77  2018-01-22  Remittance Prices Worldwide (Receiving Countries)  RWR
# 78  2020-07-10                                           ICP 2017  IC7
# 79  2020-06-19                                         PEFA_GRPFM  GRP
# 80  2020-07-25         Gender Disaggregated Labor Database (GDLD)  GDL
#
#    description url dataavailability metadataavailability concepts
# id
# 1                                 Y                    Y        3
# 2                                 Y                    Y        3
# 3                                 Y                    Y        3
# 5                                 Y                    Y        3
# 6                                 Y                    Y        3
# ..         ...  ..              ...                  ...      ...
# 76                                Y                    N        3
# 77                                Y                    N        3
# 78                                Y                    Y        4
# 79                                Y                    Y        4
# 80                                Y                    N        4
#
# [62 rows x 8 columns]

# %% [markdown]
# As we saw before, World Bank data is compherensive and include different databases as you see above. Before moving forward, we should define which one we want to work with. For the sake of practice, we choose number 2 (2 is the number of the data source), which is `World Development Indicators`. To make a selection, we specify the source number, which is denoted on the left of the databases. It is 2 for `World Development Indicators`. Once we denote the source number as 2, we have full list of variables that `World Development Indicators` includes:

# %%
wb.search_indicators('', source=2)
# Out:
#                                                                 name unit  \
# id
# AG.AGR.TRAC.NO                      Agricultural machinery, tractors
# AG.CON.FERT.PT.ZS  Fertilizer consumption (% of fertilizer produc...
# AG.CON.FERT.ZS     Fertilizer consumption (kilograms per hectare ...
# AG.LND.AGRI.K2                            Agricultural land (sq. km)
# AG.LND.AGRI.ZS                    Agricultural land (% of land area)
# ...                                                              ...  ...
# VC.IDP.TOCV        Internally displaced persons, total displaced ...
# VC.IHR.PSRC.FE.P5  Intentional homicides, female (per 100,000 fem...
# VC.IHR.PSRC.MA.P5     Intentional homicides, male (per 100,000 male)
# VC.IHR.PSRC.P5            Intentional homicides (per 100,000 people)
# VC.PKP.TOTL.UN     Presence of peace keepers (number of troops, p...
#
#                                          source  \
# id
# AG.AGR.TRAC.NO     World Development Indicators
# AG.CON.FERT.PT.ZS  World Development Indicators
# AG.CON.FERT.ZS     World Development Indicators
# AG.LND.AGRI.K2     World Development Indicators
# AG.LND.AGRI.ZS     World Development Indicators
# ...                                         ...
# VC.IDP.TOCV        World Development Indicators
# VC.IHR.PSRC.FE.P5  World Development Indicators
# VC.IHR.PSRC.MA.P5  World Development Indicators
# VC.IHR.PSRC.P5     World Development Indicators
# VC.PKP.TOTL.UN     World Development Indicators
#
#                                                           sourceNote  \
# id
# AG.AGR.TRAC.NO     Agricultural machinery refers to the number of...
# AG.CON.FERT.PT.ZS  Fertilizer consumption measures the quantity o...
# AG.CON.FERT.ZS     Fertilizer consumption measures the quantity o...
# AG.LND.AGRI.K2     Agricultural land refers to the share of land ...
# AG.LND.AGRI.ZS     Agricultural land refers to the share of land ...
# ...                                                              ...
# VC.IDP.TOCV        Internally displaced persons are defined accor...
# VC.IHR.PSRC.FE.P5  Intentional homicides, female are estimates of...
# VC.IHR.PSRC.MA.P5  Intentional homicides, male are estimates of u...
# VC.IHR.PSRC.P5     Intentional homicides are estimates of unlawfu...
# VC.PKP.TOTL.UN     Presence of peacebuilders and peacekeepers are...
#
#                                                   sourceOrganization  \
# id
# AG.AGR.TRAC.NO     Food and Agriculture Organization, electronic ...
# AG.CON.FERT.PT.ZS  Food and Agriculture Organization, electronic ...
# AG.CON.FERT.ZS     Food and Agriculture Organization, electronic ...
# AG.LND.AGRI.K2     Food and Agriculture Organization, electronic ...
# AG.LND.AGRI.ZS     Food and Agriculture Organization, electronic ...
# ...                                                              ...
# VC.IDP.TOCV        The Internal Displacement Monitoring Centre (h...
# VC.IHR.PSRC.FE.P5  UN Office on Drugs and Crime's International H...
# VC.IHR.PSRC.MA.P5  UN Office on Drugs and Crime's International H...
# VC.IHR.PSRC.P5     UN Office on Drugs and Crime's International H...
# VC.PKP.TOTL.UN     UN Department of Peacekeeping Operations, http...
#
#                                                               topics
# id
# AG.AGR.TRAC.NO                     Agriculture & Rural Development
# AG.CON.FERT.PT.ZS                  Agriculture & Rural Development
# AG.CON.FERT.ZS                     Agriculture & Rural Development
# AG.LND.AGRI.K2      Agriculture & Rural Development  ,Climate Change
# AG.LND.AGRI.ZS     Agriculture & Rural Development  ,Climate Chan...
# ...                                                              ...
# VC.IDP.TOCV                                           Public Sector
# VC.IHR.PSRC.FE.P5
# VC.IHR.PSRC.MA.P5
# VC.IHR.PSRC.P5                                        Public Sector
# VC.PKP.TOTL.UN                                        Public Sector
#
# [1431 rows x 6 columns]

# %% [markdown]
# Suppose that we want to retrieve consumer price index data but do not know how to call it. It is easy just use the keyword such as inflation or price. In order to call the variable, we use the abbreviation, on the left hand side of the variable. Once we type `inflation` keyword, we have the following:

# %%
wb.search_indicators('unemployment', source=2)
# Out:
#                                                                        name  \
# id
# per_lm_alllm.adq_pop_tot  Adequacy of unemployment benefits and ALMP (% ...
# per_lm_alllm.ben_q1_tot   Benefit incidence of unemployment benefits and...
# per_lm_alllm.cov_pop_tot  Coverage of unemployment benefits and ALMP (% ...
# per_lm_alllm.cov_q1_tot   Coverage of unemployment benefits and ALMP in ...
# per_lm_alllm.cov_q2_tot   Coverage of unemployment benefits and ALMP in ...
# per_lm_alllm.cov_q3_tot   Coverage of unemployment benefits and ALMP in ...
# per_lm_alllm.cov_q4_tot   Coverage of unemployment benefits and ALMP in ...
# per_lm_alllm.cov_q5_tot   Coverage of unemployment benefits and ALMP in ...
# SL.UEM.1524.FE.NE.ZS      Unemployment, youth female (% of female labor ...
# SL.UEM.1524.FE.ZS         Unemployment, youth female (% of female labor ...
# SL.UEM.1524.MA.NE.ZS      Unemployment, youth male (% of male labor forc...
# SL.UEM.1524.MA.ZS         Unemployment, youth male (% of male labor forc...
# SL.UEM.1524.NE.ZS         Unemployment, youth total (% of total labor fo...
# SL.UEM.1524.ZS            Unemployment, youth total (% of total labor fo...
# SL.UEM.ADVN.FE.ZS         Unemployment with advanced education, female (...
# SL.UEM.ADVN.MA.ZS         Unemployment with advanced education, male (% ...
# SL.UEM.ADVN.ZS            Unemployment with advanced education (% of tot...
# SL.UEM.BASC.FE.ZS         Unemployment with basic education, female (% o...
# SL.UEM.BASC.MA.ZS         Unemployment with basic education, male (% of ...
# SL.UEM.BASC.ZS            Unemployment with basic education (% of total ...
# SL.UEM.INTM.FE.ZS         Unemployment with intermediate education, fema...
# SL.UEM.INTM.MA.ZS         Unemployment with intermediate education, male...
# SL.UEM.INTM.ZS            Unemployment with intermediate education (% of...
# SL.UEM.TOTL.FE.NE.ZS      Unemployment, female (% of female labor force)...
# SL.UEM.TOTL.FE.ZS         Unemployment, female (% of female labor force)...
# SL.UEM.TOTL.MA.NE.ZS      Unemployment, male (% of male labor force) (na...
# SL.UEM.TOTL.MA.ZS         Unemployment, male (% of male labor force) (mo...
# SL.UEM.TOTL.NE.ZS         Unemployment, total (% of total labor force) (...
# SL.UEM.TOTL.ZS            Unemployment, total (% of total labor force) (...
#
#                          unit                        source  \
# id
# per_lm_alllm.adq_pop_tot       World Development Indicators
# per_lm_alllm.ben_q1_tot        World Development Indicators
# per_lm_alllm.cov_pop_tot       World Development Indicators
# per_lm_alllm.cov_q1_tot        World Development Indicators
# per_lm_alllm.cov_q2_tot        World Development Indicators
# per_lm_alllm.cov_q3_tot        World Development Indicators
# per_lm_alllm.cov_q4_tot        World Development Indicators
# per_lm_alllm.cov_q5_tot        World Development Indicators
# SL.UEM.1524.FE.NE.ZS           World Development Indicators
# SL.UEM.1524.FE.ZS              World Development Indicators
# SL.UEM.1524.MA.NE.ZS           World Development Indicators
# SL.UEM.1524.MA.ZS              World Development Indicators
# SL.UEM.1524.NE.ZS              World Development Indicators
# SL.UEM.1524.ZS                 World Development Indicators
# SL.UEM.ADVN.FE.ZS              World Development Indicators
# SL.UEM.ADVN.MA.ZS              World Development Indicators
# SL.UEM.ADVN.ZS                 World Development Indicators
# SL.UEM.BASC.FE.ZS              World Development Indicators
# SL.UEM.BASC.MA.ZS              World Development Indicators
# SL.UEM.BASC.ZS                 World Development Indicators
# SL.UEM.INTM.FE.ZS              World Development Indicators
# SL.UEM.INTM.MA.ZS              World Development Indicators
# SL.UEM.INTM.ZS                 World Development Indicators
# SL.UEM.TOTL.FE.NE.ZS           World Development Indicators
# SL.UEM.TOTL.FE.ZS              World Development Indicators
# SL.UEM.TOTL.MA.NE.ZS           World Development Indicators
# SL.UEM.TOTL.MA.ZS              World Development Indicators
# SL.UEM.TOTL.NE.ZS              World Development Indicators
# SL.UEM.TOTL.ZS                 World Development Indicators
#
#                                                                  sourceNote  \
# id
# per_lm_alllm.adq_pop_tot  Total transfer amount received by all benefici...
# per_lm_alllm.ben_q1_tot   Percentage of benefits going to the 1st quinti...
# per_lm_alllm.cov_pop_tot  Percentage of population participating in Soci...
# per_lm_alllm.cov_q1_tot   Percentage of population participating in Soci...
# per_lm_alllm.cov_q2_tot   Percentage of population participating in Soci...
# per_lm_alllm.cov_q3_tot   Percentage of population participating in Soci...
# per_lm_alllm.cov_q4_tot   Percentage of population participating in Soci...
# per_lm_alllm.cov_q5_tot   Percentage of population participating in Soci...
# SL.UEM.1524.FE.NE.ZS      Youth unemployment refers to the share of the ...
# SL.UEM.1524.FE.ZS         Youth unemployment refers to the share of the ...
# SL.UEM.1524.MA.NE.ZS      Youth unemployment refers to the share of the ...
# SL.UEM.1524.MA.ZS         Youth unemployment refers to the share of the ...
# SL.UEM.1524.NE.ZS         Youth unemployment refers to the share of the ...
# SL.UEM.1524.ZS            Youth unemployment refers to the share of the ...
# SL.UEM.ADVN.FE.ZS         The percentage of the labor force with an adva...
# SL.UEM.ADVN.MA.ZS         The percentage of the labor force with an adva...
# SL.UEM.ADVN.ZS            The percentage of the labor force with an adva...
# SL.UEM.BASC.FE.ZS         The percentage of the labor force with a basic...
# SL.UEM.BASC.MA.ZS         The percentage of the labor force with a basic...
# SL.UEM.BASC.ZS            The percentage of the labor force with a basic...
# SL.UEM.INTM.FE.ZS         The percentage of the labor force with an inte...
# SL.UEM.INTM.MA.ZS         The percentage of the labor force with an inte...
# SL.UEM.INTM.ZS            The percentage of the labor force with an inte...
# SL.UEM.TOTL.FE.NE.ZS      Unemployment refers to the share of the labor ...
# SL.UEM.TOTL.FE.ZS         Unemployment refers to the share of the labor ...
# SL.UEM.TOTL.MA.NE.ZS      Unemployment refers to the share of the labor ...
# SL.UEM.TOTL.MA.ZS         Unemployment refers to the share of the labor ...
# SL.UEM.TOTL.NE.ZS         Unemployment refers to the share of the labor ...
# SL.UEM.TOTL.ZS            Unemployment refers to the share of the labor ...
#
#                                                          sourceOrganization  \
# id
# per_lm_alllm.adq_pop_tot                                             ASPIRE
# per_lm_alllm.ben_q1_tot                                              ASPIRE
# per_lm_alllm.cov_pop_tot                                             ASPIRE
# per_lm_alllm.cov_q1_tot                                              ASPIRE
# per_lm_alllm.cov_q2_tot                                              ASPIRE
# per_lm_alllm.cov_q3_tot                                              ASPIRE
# per_lm_alllm.cov_q4_tot                                              ASPIRE
# per_lm_alllm.cov_q5_tot                                              ASPIRE
# SL.UEM.1524.FE.NE.ZS      International Labour Organization, ILOSTAT dat...
# SL.UEM.1524.FE.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.1524.MA.NE.ZS      International Labour Organization, ILOSTAT dat...
# SL.UEM.1524.MA.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.1524.NE.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.1524.ZS            International Labour Organization, ILOSTAT dat...
# SL.UEM.ADVN.FE.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.ADVN.MA.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.ADVN.ZS            International Labour Organization, ILOSTAT dat...
# SL.UEM.BASC.FE.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.BASC.MA.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.BASC.ZS            International Labour Organization, ILOSTAT dat...
# SL.UEM.INTM.FE.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.INTM.MA.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.INTM.ZS            International Labour Organization, ILOSTAT dat...
# SL.UEM.TOTL.FE.NE.ZS      International Labour Organization, ILOSTAT dat...
# SL.UEM.TOTL.FE.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.TOTL.MA.NE.ZS      International Labour Organization, ILOSTAT dat...
# SL.UEM.TOTL.MA.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.TOTL.NE.ZS         International Labour Organization, ILOSTAT dat...
# SL.UEM.TOTL.ZS            International Labour Organization, ILOSTAT dat...
#
#                                                                      topics
# id
# per_lm_alllm.adq_pop_tot                          Social Protection & Labor
# per_lm_alllm.ben_q1_tot                           Social Protection & Labor
# per_lm_alllm.cov_pop_tot                          Social Protection & Labor
# per_lm_alllm.cov_q1_tot                           Social Protection & Labor
# per_lm_alllm.cov_q2_tot                           Social Protection & Labor
# per_lm_alllm.cov_q3_tot                           Social Protection & Labor
# per_lm_alllm.cov_q4_tot                           Social Protection & Labor
# per_lm_alllm.cov_q5_tot                           Social Protection & Labor
# SL.UEM.1524.FE.NE.ZS                              Social Protection & Labor
# SL.UEM.1524.FE.ZS                          Social Protection & Labor,Gender
# SL.UEM.1524.MA.NE.ZS                              Social Protection & Labor
# SL.UEM.1524.MA.ZS                          Social Protection & Labor,Gender
# SL.UEM.1524.NE.ZS                                 Social Protection & Labor
# SL.UEM.1524.ZS                                    Social Protection & Labor
# SL.UEM.ADVN.FE.ZS                                 Social Protection & Labor
# SL.UEM.ADVN.MA.ZS                                 Social Protection & Labor
# SL.UEM.ADVN.ZS                                    Social Protection & Labor
# SL.UEM.BASC.FE.ZS                                 Social Protection & Labor
# SL.UEM.BASC.MA.ZS                                 Social Protection & Labor
# SL.UEM.BASC.ZS                                    Social Protection & Labor
# SL.UEM.INTM.FE.ZS                                 Social Protection & Labor
# SL.UEM.INTM.MA.ZS                                 Social Protection & Labor
# SL.UEM.INTM.ZS                                    Social Protection & Labor
# SL.UEM.TOTL.FE.NE.ZS                              Social Protection & Labor
# SL.UEM.TOTL.FE.ZS         Education ,Social Protection & Labor,Gender,So...
# SL.UEM.TOTL.MA.NE.ZS                              Social Protection & Labor
# SL.UEM.TOTL.MA.ZS         Education ,Social Protection & Labor,Gender,So...
# SL.UEM.TOTL.NE.ZS                                 Social Protection & Labor
# SL.UEM.TOTL.ZS                         Education ,Social Protection & Labor

# %% [markdown]
# `FP.CPI.TOTL.ZG` is the input we feed the code while extracting the consumer prices. Now, it is time to decide which country we are going examine. Let's continue with `USA` but I again do not know how to call it. No worries, the following code is for you. Just type a keyword for `USA`:

# %%
wb.search_countries('united')
# Out:
#     iso2Code                  name                      region adminregion  \
# id
# ARE       AE  United Arab Emirates  Middle East & North Africa
# GBR       GB        United Kingdom       Europe & Central Asia
# USA       US         United States               North America
#
#      incomeLevel     lendingType      capitalCity  longitude  latitude
# id
# ARE  High income  Not classified        Abu Dhabi  54.370500   24.4764
# GBR  High income  Not classified           London  -0.126236   51.5002
# USA  High income  Not classified  Washington D.C. -77.032000   38.8895

# %% [markdown]
# So, `USA` is the abbreviation that we are about to use. Final step before extracting the data is deciding the time interval. Suppose that our analysis period covers between 01-01-2010 and 12-01-2019.

# %% [markdown]
# Using `wbdata.get_series`, we form our data for USA inflation.

# %%
unemployment = wb.get_series('SL.UEM.TOTL.NE.ZS',country='USA', date='2010:2020', id_or_value='id', simplify_index=True)
unemployment
# Out:
# Year
# 2010    9.6334
# 2011    8.9492
# 2012    8.0694
# 2013    7.3749
# 2014    6.1675
# 2015    5.2800
# 2016    4.8692
# 2017    4.3552
# 2018    3.8956
# 2019    3.6692
# Name: SL.UEM.TOTL.NE.ZS, dtype: float64

# %%
unemployment_extended = wb.get_series('SL.UEM.TOTL.NE.ZS',country=['USA','GB'], date='2010:2020', id_or_value='id', simplify_index=True)
unemployment_extended
# Out:
# Country  Year
# GBR      2010    7.7866
#          2011    8.0377
#          2012    7.8846
#          2013    7.5242
#          2014    6.1096
#          2015    5.3003
#          2016    4.8097
#          2017    4.3300
#          2018    3.9959
#          2019    3.7372
# USA      2010    9.6334
#          2011    8.9492
#          2012    8.0694
#          2013    7.3749
#          2014    6.1675
#          2015    5.2800
#          2016    4.8692
#          2017    4.3552
#          2018    3.8956
#          2019    3.6692
# Name: SL.UEM.TOTL.NE.ZS, dtype: float64

# %% [markdown]
# Let's now try with multiple countries, for instance Germany, Turkey, France, with a different data, say per capita Gross Domestic Product. First, we search for the variable and the name of the countries:

# %%
wb.search_indicators('gdp', source=2)
# Out:
#                                                                    name unit  \
# id
# BG.GSR.NFSV.GD.ZS                          Trade in services (% of GDP)
# BM.KLT.DINV.WD.GD.ZS  Foreign direct investment, net outflows (% of ...
# BN.CAB.XOKA.GD.ZS                    Current account balance (% of GDP)
# BX.KLT.DINV.WD.GD.ZS  Foreign direct investment, net inflows (% of GDP)
# BX.TRF.PWKR.DT.GD.ZS          Personal remittances, received (% of GDP)
# ...                                                                 ...  ...
# SH.STA.MMRT           Maternal mortality ratio (modeled estimate, pe...
# SH.XPD.CHEX.GD.ZS                 Current health expenditure (% of GDP)
# SH.XPD.GHED.GD.ZS     Domestic general government health expenditure...
# SL.GDP.PCAP.EM.KD         GDP per person employed (constant 2017 PPP $)
# TG.VAL.TOTL.GD.ZS                          Merchandise trade (% of GDP)
#
#                                             source  \
# id
# BG.GSR.NFSV.GD.ZS     World Development Indicators
# BM.KLT.DINV.WD.GD.ZS  World Development Indicators
# BN.CAB.XOKA.GD.ZS     World Development Indicators
# BX.KLT.DINV.WD.GD.ZS  World Development Indicators
# BX.TRF.PWKR.DT.GD.ZS  World Development Indicators
# ...                                            ...
# SH.STA.MMRT           World Development Indicators
# SH.XPD.CHEX.GD.ZS     World Development Indicators
# SH.XPD.GHED.GD.ZS     World Development Indicators
# SL.GDP.PCAP.EM.KD     World Development Indicators
# TG.VAL.TOTL.GD.ZS     World Development Indicators
#
#                                                              sourceNote  \
# id
# BG.GSR.NFSV.GD.ZS     Trade in services is the sum of service export...
# BM.KLT.DINV.WD.GD.ZS  Foreign direct investment refers to direct inv...
# BN.CAB.XOKA.GD.ZS     Current account balance is the sum of net expo...
# BX.KLT.DINV.WD.GD.ZS  Foreign direct investment are the net inflows ...
# BX.TRF.PWKR.DT.GD.ZS  Personal remittances comprise personal transfe...
# ...                                                                 ...
# SH.STA.MMRT           Maternal mortality ratio is the number of wome...
# SH.XPD.CHEX.GD.ZS     Level of current health expenditure expressed ...
# SH.XPD.GHED.GD.ZS     Public expenditure on health from domestic sou...
# SL.GDP.PCAP.EM.KD     GDP per person employed is gross domestic prod...
# TG.VAL.TOTL.GD.ZS     Merchandise trade as a share of GDP is the sum...
#
#                                                      sourceOrganization  \
# id
# BG.GSR.NFSV.GD.ZS     International Monetary Fund, Balance of Paymen...
# BM.KLT.DINV.WD.GD.ZS  International Monetary Fund, Balance of Paymen...
# BN.CAB.XOKA.GD.ZS     International Monetary Fund, Balance of Paymen...
# BX.KLT.DINV.WD.GD.ZS  International Monetary Fund, International Fin...
# BX.TRF.PWKR.DT.GD.ZS  World Bank staff estimates based on IMF balanc...
# ...                                                                 ...
# SH.STA.MMRT           WHO, UNICEF, UNFPA, World Bank Group, and the ...
# SH.XPD.CHEX.GD.ZS     World Health Organization Global Health Expend...
# SH.XPD.GHED.GD.ZS     World Health Organization Global Health Expend...
# SL.GDP.PCAP.EM.KD     Derived using data from International Labour O...
# TG.VAL.TOTL.GD.ZS     World Trade Organization, and World Bank GDP e...
#
#                                                                  topics
# id
# BG.GSR.NFSV.GD.ZS                 Economy & Growth,Private Sector,Trade
# BM.KLT.DINV.WD.GD.ZS                 Economy & Growth,Financial Sector
# BN.CAB.XOKA.GD.ZS                                      Economy & Growth
# BX.KLT.DINV.WD.GD.ZS  Economy & Growth,Financial Sector ,Climate Change
# BX.TRF.PWKR.DT.GD.ZS                 Economy & Growth,Financial Sector
# ...                                                                 ...
# SH.STA.MMRT                           Health ,Gender,Aid Effectiveness
# SH.XPD.CHEX.GD.ZS                                               Health
# SH.XPD.GHED.GD.ZS                                               Health
# SL.GDP.PCAP.EM.KD                             Social Protection & Labor
# TG.VAL.TOTL.GD.ZS                                  Private Sector,Trade
#
# [96 rows x 6 columns]

# %% [markdown]
# `NY.GDP.PCAP.CD` is the short name of the `GDP per capita (current US$)`

# %%
wb.search_countries('india')
# Out:
#     iso2Code   name      region adminregion          incomeLevel lendingType  \
# id
# IND       IN  India  South Asia  South Asia  Lower middle income        IBRD
#
#     capitalCity  longitude  latitude
# id
# IND   New Delhi     77.225   28.6353

# %%
wb.search_countries('turkey')
# Out:
# TUR	Turkey

# %%
wb.search_countries('china')
# Out:
#     iso2Code                  name               region  \
# id
# CHN       CN                 China  East Asia & Pacific
# HKG       HK  Hong Kong SAR, China  East Asia & Pacific
# MAC       MO      Macao SAR, China  East Asia & Pacific
# TWN       TW         Taiwan, China  East Asia & Pacific
#
#                                      adminregion          incomeLevel  \
# id
# CHN  East Asia & Pacific (excluding high income)  Upper middle income
# HKG                                                       High income
# MAC                                                       High income
# TWN                                                       High income
#
#         lendingType capitalCity  longitude  latitude
# id
# CHN            IBRD     Beijing    116.286   40.0495
# HKG  Not classified                114.109   22.3964
# MAC  Not classified                113.550   22.1667
# TWN  Not classified                    NaN       NaN

# %%
gdp = wb.get_series('NY.GDP.PCAP.CD',country=['IND','TUR','CHN'], date='2010:2020', id_or_value='id', simplify_index=True )
gdp
# Out:
# Country  Year
# CHN      2010     4550.453596
#          2011     5618.132491
#          2012     6316.918863
#          2013     7050.645920
#          2014     7678.599432
#          2015     8066.942424
#          2016     8147.938148
#          2017     8879.438149
#          2018     9976.676822
#          2019    10261.679128
# IND      2010     1357.563719
#          2011     1458.103527
#          2012     1443.879529
#          2013     1449.605912
#          2014     1573.881492
#          2015     1605.605434
#          2016     1732.564262
#          2017     1981.651050
#          2018     2005.863005
#          2019     2104.145900
# TUR      2010    10672.389246
#          2011    11335.510510
#          2012    11707.259712
#          2013    12519.391426
#          2014    12095.854572
#          2015    10948.724607
#          2016    10820.633842
#          2017    10513.648432
#          2018     9370.176355
#          2019     9042.492983
# Name: NY.GDP.PCAP.CD, dtype: float64

# %% [markdown]
# # Conclusion

# %% [markdown]
# To wrap up, this lesson is an important and complementary part of the subsequent Python for finance lesson because it facilitates our access to the data sources and makes us save considerable amount of time.
