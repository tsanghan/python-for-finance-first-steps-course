# %% [markdown]
# # Asset Pricing Models and Its Application in Python
# ## Abdullah Karasan

# %% [markdown]
# Financial investment decision is a function of risk and return, which are positively related to each other. Investor tries to obtain highest possible return while mitigating the risk as much as possible. So, in a nutshell, investor tend to invest in an asset with best risk-return combination. But the question is how can we estimate the best risk-return combination?

# %% [markdown]
# This lesson tries to tackle this question using two celebrated models. In this part of the lesson, we will discuss the two prominent models about asset valuation:
# * Capital Asset Pricing Model
# * Arbitrage Pricing Theorem

# %% [markdown]
# ## 1. Capital Asset Pricing Model (CAPM)

# %% [markdown]
# It is an easy task to measure return of an asset, which is nothing but a change in an asset's value based on previous period. How about risk? It is exactly where `Markowitz's Portfolio Theory`comes into the picture. Markowitz's article titled ["Portfolio Selection"](https://www.math.ust.hk/~maykwok/courses/ma362/07F/markowitz_JF.pdf) provides a clear definition of what had hitherto been unambiguous.

# %% [markdown]
# This trade-off is defined as the selection problem of the portfolio mean and variance of the assets, and given the risk level the theory has suggested that high expected return should be selected. Expected return and risk are given as follows:

# %% [markdown]
# $$ \text{Expected Return}=\mathbb{E}(R_i)$$
# $$\text{Risk}=\sigma (R_i)$$

# %% [markdown]
# where $R_i$ is the return of ith asset and $\mathbb{E}$ denotes expectation operator, and $\sigma$ represents the standard deviation of return. Thus, standard deviation is assumed to be a risk of an asset and this approach paves the way for further analysis.

# %% [markdown]
# Starting with Markowitz's contribution, risk-return relationship of an asset is well-founded as new approaches emerges. Of these approaches. Capital Asset Pricing Model is the one of the most prominents one.

# %% [markdown]
# The CAPM is based on the idea that the individual investor can make a combination between the borrower portfolios and the lender portfolios, to organize his own risk and to create an optimal portfolio among the risky assets. CAPM, suggested by [Sharpe (1964)](http://efinance.org.cn/cn/fm/Capital%20Asset%20Prices%20A%20Theory%20of%20Market%20Equilibrium%20under%20Conditions%20of%20Risk.pdf), [Lintner (1965)](http://www.empirical.net/wp-content/uploads/2014/12/Lintner-The-Valuation-of-Risk-Assets-and-the-Selection-of-Risky-Investments-in-Stock-Portfolios-and-Capital-Budgets.pdf), and [Black (1972)](http://www.stat.ucla.edu/~nchristo/statistics_c183_c283/fischer_black_trace_out.pdf) , is a model investigating the systematic risk and return in a competitive market.

# %% [markdown]
# As we have discussed, the primary motivation of an investor in forming a best risk-return portfolio is to mitigate the risk while having highest return but it is not possible to make all risks go away. That is to say, there are some risks that an investor can mitigate and some he/she cannot. By diversification, which is simply forming a portfolio with assets having high risk-return relationship and with assets having low risk-return relationship, the risk can be reduced to certain level. But what is this level?

# %% [markdown]
# In order to better understand and handle the risk in finance, we need to differentiate it:
# * Systematic Risk: It is the that cannot be disappeared by diversification. Therefore it is also referred to as `non-diversifiable risk`.  More specifically, random fluctuations in the value of an asset can be balanced out by holding diverse assets. Some systematic risks are:
#     * Interest rate risk
#     * Inflation risk
#     * Market risk

# %% [markdown]
# * Unsystematic Risk: It is the risk that can be mitigated through diversification. That is random fluctuations in the value of the asset can be balanced out by holding many different assets. Unsystematic risk arises from Stock-specific issues. Some unsystematic risks can be listed as:
#     * Business risk: Any Internal weakness of a company can jeopardize its profitability
#     * Financial risk: Change in capital structure allocation of a company
#     * Entrance of a new competitor

# %% [markdown]
# CAPM examines the systematic risk ($\beta$) and expected return in a competitive market. It is a parametric and univariate approach. The ultimate aim of this method is to price an individual security or a portfolio. Let's now talk about the components and the formula of CAPM:

# %% [markdown]
# $$\mathbb{E}(R_i)=\alpha_i+\beta_i\mathbb{E}(R_m)$$

# %% [markdown]
# where
#  * $R_i$: Expected excess return of the $i^{th}$ stock
#  * $\alpha_i$: asset’s return\loss coming from technical analysis
#  * $R_m$: Expected excess market return
#  * $\beta_{i}$: Slope coefficient

# %% [markdown]
# Here, excess return represents the portion of an individual stock or market return above the `risk free rate`. Or it can be formulated as:

# %% [markdown]
# $$\mathbb{E}(R_i)=\mathbb{E}(r_i)-r_f$$

# %% [markdown]
# where $r_f$ is risk free rate and $r_i$ is the individual stock return. So, excess return checks if an asset yields  larger return than a safe asset. If so, it is a motivation to invest, otherwise, investor prefer to invest in a safe asset whose return is low but guaranteed.

# %% [markdown]
# The result, denoted as $`\mathbb{E}(R_i)`$, is also the required return or discount rate used in valuing an asset or a project that we discuss in NPV lesson:

# %% [markdown]
# Required Rate of Return = Risk Free Rate of Return + Beta*(Market Return – Risk Free Rate of Return)

# %% [markdown]
# We need to put special emphasize on $\beta$, which shows the extent to which an investment adds risk to a portfolio. Put differently, it is a measure of systematic risk of a stock in comparison to the market. It is also indicates the correlation between individual stock and market:

# %% [markdown]
# * If the $\beta$>1, stock is riskier than the benchmark market
# * If the $\beta$=1, stock is as riskier as the benchmark market
# * If the $\beta$<1, stock is as less riskier as than the benchmark market

# %% [markdown]
# Hence, beta coefficient indicates the ratio between the covariance of individual stock return and market return and the stock market return variance:

# %% [markdown]
# $$\beta_i = \frac{\text{Cov}(r_i, r_m)}{\text{Var}(r_m)}$$

# %% [markdown]
# In econometrical approach, CAPM can be defined as:

# %% [markdown]
# $$
# r_i-r_f= \alpha_i + \beta_{i}(\mathbb{E}(r_m)-r_f) + \epsilon_i
# $$

# %% [markdown]
# where
#  * $\epsilon_i$: Error term

# %% [markdown]
# The CAPM provides insights about `Security Market Line` (SML) and `Capital Market Line` (CML). The CML illustrates rate of return for a single set of optimal portfolio shown below:

# %% [markdown]
# <img src="assets/CML.png" alt="Capital Market Line" style="width:200;height:400px;">

# %% [markdown]
# Source: `Mastering Python for Finance` Weiming (2015)

# %% [markdown]
# The dots we see in the `CML`graph above represents security return. Asset return locating above the CML represent high return-risk ratio. On the other hand, asset returns, below the CML, implies low return-risk ratio. So, it would be a wise to invest in an asset above the `CML` line.

# %% [markdown]
# `SML`, on the other hand, exhibits the linear relationship between expected asset returns and betas obtained from CAPM. All the correctly priced securities are plotted on the SML. If the assets lie above the SML line, the assets are undervalued due to the higher return for a given amount of risk. Conversely, the assets lie below the SML are overvalued because it return of this stock is lower for a given amount of risk.

# %% [markdown]
# <img src="assets/SML.png" alt="Security Market Line" style="width:100;height:300px;">

# %% [markdown]
# **Source:** Shapiro, Foundations of Finance

# %% [markdown]
# Enough theory, let's begin the empirical part. First step, as always, is to import the necessary Python libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import seaborn as sns
import warnings
import yfinance as yf
import seaborn as sns; sns.set()
yf.pdr_override() 
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
#  In this part, instead of visiting a website and downloading the data to our local computer, we directly access to `yahoo finance` and retrieve the data as  we have learned in the previous lesson. To compare the performance of the companies, we will run CAPM analyses with three difference companies operating in telecomunication sector. These companies are `Comcast`, `AT&T`,`Verizon` and the market these stocks are listed is S&P-500. We use tickers to retreive data from yahoo finance:
#  * CMCSA: Comcast
#  * T: AT&T
#  * VZ: Verizon
#  * ^GSPC: S&P-500

# %% [markdown]
# The analysis covers the business day for the period of 01-01-2016 and 01-01-2020 with monthly stock price data.

# %%
stocks = ['CMCSA','T','VZ','^GSPC']
start = datetime.datetime(2016,1,1)
end = datetime.datetime(2020,1,1)
stock_prices = yf.download(stocks,start=start,end = end, interval='1mo')
# Out:
# [*********************100%***********************]  4 of 4 downloaded

# %%
stock_prices.head()
# Out:
#            Adj Close                         Close                         \
#                CMCSA      T     VZ    ^GSPC  CMCSA      T     VZ    ^GSPC
# Date
# 2016-01-01     25.56  28.15  40.90  1940.24  27.85  36.06  49.97  1940.24
# 2016-01-04       NaN    NaN    NaN      NaN    NaN    NaN    NaN      NaN
# 2016-02-01     26.60  29.25  42.03  1932.23  28.86  36.95  50.73  1932.23
# 2016-03-01     28.15  31.01  44.81  2059.74  30.54  39.17  54.08  2059.74
# 2016-04-01     28.00  30.73  42.20  2065.30  30.38  38.82  50.94  2065.30
#
#              High         ...    Low            Open                         \
#             CMCSA      T  ...     VZ    ^GSPC  CMCSA      T     VZ    ^GSPC
# Date                      ...
# 2016-01-01  28.02  36.06  ...  43.79  1812.29  27.58  34.08  45.67  2038.20
# 2016-01-04    NaN    NaN  ...    NaN      NaN    NaN    NaN    NaN      NaN
# 2016-02-01  29.85  37.50  ...  49.27  1810.10  27.53  36.04  49.94  1936.94
# 2016-03-01  30.68  39.72  ...  50.98  1937.09  29.11  37.10  50.99  1937.09
# 2016-04-01  31.45  39.36  ...  49.47  2033.80  30.30  38.67  53.32  2056.62
#
#                  Volume
#                   CMCSA            T           VZ         ^GSPC
# Date
# 2016-01-01  532587400.0  677721800.0  416446100.0  9.240977e+10
# 2016-01-04          NaN          NaN          NaN           NaN
# 2016-02-01  608842000.0  577261900.0  379201400.0  9.304956e+10
# 2016-03-01  400644600.0  508161600.0  298263500.0  9.263942e+10
# 2016-04-01  425409600.0  452326800.0  312846700.0  8.112499e+10
#
# [5 rows x 24 columns]

# %%
stock_prices=stock_prices['Close']

# %%
stock_prices.dropna(inplace=True)

# %% [markdown]
# Summary statistics is a very first step to explore the dataset. Main statistics such as mean, standard deviation, minimum, maximum etc., can be calculated via `.describe()` in Python. Initial observation tells us that the price level and volatility (represented by standard deviation) of S&P-500 is quite different from the rest of the stocks.

# %%
stock_prices.describe()
# Out:
#            CMCSA          T         VZ        ^GSPC
# count  48.000000  48.000000  48.000000    48.000000
# mean   37.152708  36.334167  52.736667  2560.539167
# std     4.647971   3.898660   4.405864   337.100990
# min    27.850000  28.540000  44.660000  1932.230000
# 25%    33.507500  32.605000  49.265000  2268.860000
# 50%    37.480000  37.165000  52.155000  2612.855000
# 75%    40.490000  39.097500  55.935000  2818.170000
# max    45.080000  43.290000  61.400000  3230.780000

# %% [markdown]
# As the caret sign `^` in the ticker of S&P-500 might cause problem in coding, I prefer rename this column before proceeding:

# %%
stock_prices=stock_prices.rename({'^GSPC':'GSPC'}, axis='columns')

# %% [markdown]
# Visualization is quite helpful in understanding what the data looks like. So, as a first step, it is encouraged to plot the data and increase the awareness about it. Aside from the AT&T, what we see in the below-given plots are stock prices follow a volatile path with upward trend. Stock price of AT&T, on the other hand, declines dramatically and then recovered.

# %%
k=1
for i in range(0, len(stock_prices.columns)):
    sns.set
    plt.figure(figsize=(15, 5))
    plt.subplot(2, 2, k)
    plt.plot(stock_prices[stock_prices.columns[i]])
    plt.title("{}".format(stock_prices.columns[i]))
    k+=1
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Correlation coefficient tells us the extent to which variables are related. `Correlation matrix` is a tool to calculate and visualize the correlation coefficients among the variables of interest. The most striking observation is the correlation coefficient of 76% between Comcast and S&P-500 indicating that there is a high correlation between these two variables. However, it is not the case for AT&T and Verizon whose correlation coefficients with S&P-500 are -52% and 55%, respectively.

# %%
heat_corr=stock_prices.corr()
sns.heatmap(heat_corr, annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# As CAPM requires stock returns, there are various ways to calculate return in Python but `.pct_change()` is one of the most easyto-apply function. Once we calculate the return first row becomes `nan` as return for the first entry cannot be computed.

# %%
returns=stock_prices.pct_change()
returns.dropna(inplace=True)
returns.head()
# Out:
#                CMCSA         T        VZ      GSPC
# Date
# 2016-02-01  0.036266  0.024681  0.015209 -0.004128
# 2016-03-01  0.058212  0.060081  0.066036  0.065991
# 2016-04-01 -0.005239 -0.008935 -0.058062  0.002699
# 2016-05-01  0.041804  0.008501 -0.000785  0.015325
# 2016-06-01  0.030016  0.103704  0.097053  0.000911

# %% [markdown]
# Now, after having the return for three stock and one market index, extracting risk free rate allows us to compute excess return. To access the risk free rate data, we use `Fred API` as we have learned previosly. Please note that there is no single risk free rate, different researchers apply different risk free rate but the common property of these rates is that they are issued by a government, which makes them safe heaven to invest. Here, we select `3-Month Treasury Constant Maturity Rate`, which is short-term T-Bill with relatively low and safe return.

# %%
from fredapi import Fred
fred = Fred(api_key='Insert Your API key here')# or you can use my API key: 78b14ec6ba46f484b94db43694468bb1

# %%
fred.search('risk free')
# Out:
#                             id realtime_start realtime_end  \
# series id
# DGS10                    DGS10     2020-06-22   2020-06-22
# GS10                      GS10     2020-06-22   2020-06-22
# WGS10YR                WGS10YR     2020-06-22   2020-06-22
# DGS1                      DGS1     2020-06-22   2020-06-22
# GS1                        GS1     2020-06-22   2020-06-22
# WGS1YR                  WGS1YR     2020-06-22   2020-06-22
# DGS30                    DGS30     2020-06-22   2020-06-22
# DGS5                      DGS5     2020-06-22   2020-06-22
# GS5                        GS5     2020-06-22   2020-06-22
# GS30                      GS30     2020-06-22   2020-06-22
# WGS5YR                  WGS5YR     2020-06-22   2020-06-22
# DGS2                      DGS2     2020-06-22   2020-06-22
# DGS3MO                  DGS3MO     2020-06-22   2020-06-22
# WGS30YR                WGS30YR     2020-06-22   2020-06-22
# GS3M                      GS3M     2020-06-22   2020-06-22
# GS2                        GS2     2020-06-22   2020-06-22
# WGS2YR                  WGS2YR     2020-06-22   2020-06-22
# WGS3MO                  WGS3MO     2020-06-22   2020-06-22
# DGS20                    DGS20     2020-06-22   2020-06-22
# GS20                      GS20     2020-06-22   2020-06-22
# DGS1MO                  DGS1MO     2020-06-22   2020-06-22
# DGS3                      DGS3     2020-06-22   2020-06-22
# GS3                        GS3     2020-06-22   2020-06-22
# GS1M                      GS1M     2020-06-22   2020-06-22
# WGS20YR                WGS20YR     2020-06-22   2020-06-22
# WGS3YR                  WGS3YR     2020-06-22   2020-06-22
# WGS1MO                  WGS1MO     2020-06-22   2020-06-22
# DGS7                      DGS7     2020-06-22   2020-06-22
# GS7                        GS7     2020-06-22   2020-06-22
# WGS7YR                  WGS7YR     2020-06-22   2020-06-22
# DGS6MO                  DGS6MO     2020-06-22   2020-06-22
# GS6M                      GS6M     2020-06-22   2020-06-22
# WGS6MO                  WGS6MO     2020-06-22   2020-06-22
# CRESD678FRBCLE  CRESD678FRBCLE     2020-06-22   2020-06-22
# RRESD678FRBCLE  RRESD678FRBCLE     2020-06-22   2020-06-22
#
#                                                             title  \
# series id
# DGS10                     10-Year Treasury Constant Maturity Rate
# GS10                      10-Year Treasury Constant Maturity Rate
# WGS10YR                   10-Year Treasury Constant Maturity Rate
# DGS1                       1-Year Treasury Constant Maturity Rate
# GS1                        1-Year Treasury Constant Maturity Rate
# WGS1YR                     1-Year Treasury Constant Maturity Rate
# DGS30                     30-Year Treasury Constant Maturity Rate
# DGS5                       5-Year Treasury Constant Maturity Rate
# GS5                        5-Year Treasury Constant Maturity Rate
# GS30                      30-Year Treasury Constant Maturity Rate
# WGS5YR                     5-Year Treasury Constant Maturity Rate
# DGS2                       2-Year Treasury Constant Maturity Rate
# DGS3MO                    3-Month Treasury Constant Maturity Rate
# WGS30YR                   30-Year Treasury Constant Maturity Rate
# GS3M                      3-Month Treasury Constant Maturity Rate
# GS2                        2-Year Treasury Constant Maturity Rate
# WGS2YR                     2-Year Treasury Constant Maturity Rate
# WGS3MO                    3-Month Treasury Constant Maturity Rate
# DGS20                     20-Year Treasury Constant Maturity Rate
# GS20                      20-Year Treasury Constant Maturity Rate
# DGS1MO                    1-Month Treasury Constant Maturity Rate
# DGS3                       3-Year Treasury Constant Maturity Rate
# GS3                        3-Year Treasury Constant Maturity Rate
# GS1M                      1-Month Treasury Constant Maturity Rate
# WGS20YR                   20-Year Treasury Constant Maturity Rate
# WGS3YR                     3-Year Treasury Constant Maturity Rate
# WGS1MO                    1-Month Treasury Constant Maturity Rate
# DGS7                       7-Year Treasury Constant Maturity Rate
# GS7                        7-Year Treasury Constant Maturity Rate
# WGS7YR                     7-Year Treasury Constant Maturity Rate
# DGS6MO                    6-Month Treasury Constant Maturity Rate
# GS6M                      6-Month Treasury Constant Maturity Rate
# WGS6MO                    6-Month Treasury Constant Maturity Rate
# CRESD678FRBCLE  Contributions to the Cleveland Financial Stres...
# RRESD678FRBCLE  Contributions to the Cleveland Financial Stres...
#
#                observation_start observation_end              frequency  \
# series id
# DGS10                 1962-01-02      2020-06-18                  Daily
# GS10                  1953-04-01      2020-05-01                Monthly
# WGS10YR               1962-01-05      2020-06-12  Weekly, Ending Friday
# DGS1                  1962-01-02      2020-06-18                  Daily
# GS1                   1953-04-01      2020-05-01                Monthly
# WGS1YR                1962-01-05      2020-06-12  Weekly, Ending Friday
# DGS30                 1977-02-15      2020-06-18                  Daily
# DGS5                  1962-01-02      2020-06-18                  Daily
# GS5                   1953-04-01      2020-05-01                Monthly
# GS30                  1977-02-01      2020-05-01                Monthly
# WGS5YR                1962-01-05      2020-06-12  Weekly, Ending Friday
# DGS2                  1976-06-01      2020-06-18                  Daily
# DGS3MO                1982-01-04      2020-06-18                  Daily
# WGS30YR               1977-02-18      2020-06-12  Weekly, Ending Friday
# GS3M                  1982-01-01      2020-05-01                Monthly
# GS2                   1976-06-01      2020-05-01                Monthly
# WGS2YR                1976-06-04      2020-06-12  Weekly, Ending Friday
# WGS3MO                1982-01-08      2020-06-12  Weekly, Ending Friday
# DGS20                 1993-10-01      2020-06-18                  Daily
# GS20                  1953-04-01      2020-05-01                Monthly
# DGS1MO                2001-07-31      2020-06-18                  Daily
# DGS3                  1962-01-02      2020-06-18                  Daily
# GS3                   1953-04-01      2020-05-01                Monthly
# GS1M                  2001-07-01      2020-05-01                Monthly
# WGS20YR               1993-10-01      2020-06-12  Weekly, Ending Friday
# WGS3YR                1962-01-05      2020-06-12  Weekly, Ending Friday
# WGS1MO                2001-08-03      2020-06-12  Weekly, Ending Friday
# DGS7                  1969-07-01      2020-06-18                  Daily
# GS7                   1969-07-01      2020-05-01                Monthly
# WGS7YR                1969-07-04      2020-06-12  Weekly, Ending Friday
# DGS6MO                1982-01-04      2020-06-18                  Daily
# GS6M                  1982-01-01      2020-05-01                Monthly
# WGS6MO                1982-01-08      2020-06-12  Weekly, Ending Friday
# CRESD678FRBCLE        1991-09-25      2016-05-05                  Daily
# RRESD678FRBCLE        1991-09-25      2016-05-05                  Daily
#
#                frequency_short            units      units_short  \
# series id
# DGS10                        D          Percent                %
# GS10                         M          Percent                %
# WGS10YR                      W          Percent                %
# DGS1                         D          Percent                %
# GS1                          M          Percent                %
# WGS1YR                       W          Percent                %
# DGS30                        D          Percent                %
# DGS5                         D          Percent                %
# GS5                          M          Percent                %
# GS30                         M          Percent                %
# WGS5YR                       W          Percent                %
# DGS2                         D          Percent                %
# DGS3MO                       D          Percent                %
# WGS30YR                      W          Percent                %
# GS3M                         M          Percent                %
# GS2                          M          Percent                %
# WGS2YR                       W          Percent                %
# WGS3MO                       W          Percent                %
# DGS20                        D          Percent                %
# GS20                         M          Percent                %
# DGS1MO                       D          Percent                %
# DGS3                         D          Percent                %
# GS3                          M          Percent                %
# GS1M                         M          Percent                %
# WGS20YR                      W          Percent                %
# WGS3YR                       W          Percent                %
# WGS1MO                       W          Percent                %
# DGS7                         D          Percent                %
# GS7                          M          Percent                %
# WGS7YR                       W          Percent                %
# DGS6MO                       D          Percent                %
# GS6M                         M          Percent                %
# WGS6MO                       W          Percent                %
# CRESD678FRBCLE               D  Units of Stress  Units of Stress
# RRESD678FRBCLE               D  Units of Stress  Units of Stress
#
#                     seasonal_adjustment seasonal_adjustment_short  \
# series id
# DGS10           Not Seasonally Adjusted                       NSA
# GS10            Not Seasonally Adjusted                       NSA
# WGS10YR         Not Seasonally Adjusted                       NSA
# DGS1            Not Seasonally Adjusted                       NSA
# GS1             Not Seasonally Adjusted                       NSA
# WGS1YR          Not Seasonally Adjusted                       NSA
# DGS30           Not Seasonally Adjusted                       NSA
# DGS5            Not Seasonally Adjusted                       NSA
# GS5             Not Seasonally Adjusted                       NSA
# GS30            Not Seasonally Adjusted                       NSA
# WGS5YR          Not Seasonally Adjusted                       NSA
# DGS2            Not Seasonally Adjusted                       NSA
# DGS3MO          Not Seasonally Adjusted                       NSA
# WGS30YR         Not Seasonally Adjusted                       NSA
# GS3M            Not Seasonally Adjusted                       NSA
# GS2             Not Seasonally Adjusted                       NSA
# WGS2YR          Not Seasonally Adjusted                       NSA
# WGS3MO          Not Seasonally Adjusted                       NSA
# DGS20           Not Seasonally Adjusted                       NSA
# GS20            Not Seasonally Adjusted                       NSA
# DGS1MO          Not Seasonally Adjusted                       NSA
# DGS3            Not Seasonally Adjusted                       NSA
# GS3             Not Seasonally Adjusted                       NSA
# GS1M            Not Seasonally Adjusted                       NSA
# WGS20YR         Not Seasonally Adjusted                       NSA
# WGS3YR          Not Seasonally Adjusted                       NSA
# WGS1MO          Not Seasonally Adjusted                       NSA
# DGS7            Not Seasonally Adjusted                       NSA
# GS7             Not Seasonally Adjusted                       NSA
# WGS7YR          Not Seasonally Adjusted                       NSA
# DGS6MO          Not Seasonally Adjusted                       NSA
# GS6M            Not Seasonally Adjusted                       NSA
# WGS6MO          Not Seasonally Adjusted                       NSA
# CRESD678FRBCLE  Not Seasonally Adjusted                       NSA
# RRESD678FRBCLE  Not Seasonally Adjusted                       NSA
#
#                             last_updated popularity  \
# series id
# DGS10          2020-06-19 15:25:33-05:00         96
# GS10           2020-06-01 15:21:01-05:00         76
# WGS10YR        2020-06-15 15:21:04-05:00         65
# DGS1           2020-06-19 15:25:30-05:00         80
# GS1            2020-06-01 15:24:45-05:00         60
# WGS1YR         2020-06-15 15:22:12-05:00         57
# DGS30          2020-06-19 15:26:05-05:00         77
# DGS5           2020-06-19 15:25:58-05:00         76
# GS5            2020-06-01 15:25:01-05:00         56
# GS30           2020-06-01 15:25:09-05:00         55
# WGS5YR         2020-06-15 15:23:14-05:00         48
# DGS2           2020-06-19 15:24:22-05:00         76
# DGS3MO         2020-06-19 15:23:11-05:00         75
# WGS30YR        2020-06-15 15:22:06-05:00         32
# GS3M           2020-06-01 15:25:20-05:00         47
# GS2            2020-06-01 15:25:34-05:00         39
# WGS2YR         2020-06-15 15:22:06-05:00         33
# WGS3MO         2020-06-15 15:22:06-05:00         29
# DGS20          2020-06-19 15:26:04-05:00         67
# GS20           2020-06-01 15:24:41-05:00         59
# DGS1MO         2020-06-19 15:24:24-05:00         69
# DGS3           2020-06-19 15:24:21-05:00         66
# GS3            2020-06-01 15:25:30-05:00         49
# GS1M           2020-06-01 15:25:24-05:00         45
# WGS20YR        2020-06-15 15:22:07-05:00         21
# WGS3YR         2020-06-15 15:21:03-05:00         26
# WGS1MO         2020-06-15 15:23:14-05:00         13
# DGS7           2020-06-19 15:24:16-05:00         56
# GS7            2020-06-01 15:25:50-05:00         21
# WGS7YR         2020-06-15 15:22:05-05:00         21
# DGS6MO         2020-06-19 15:24:20-05:00         50
# GS6M           2020-06-01 15:25:47-05:00         24
# WGS6MO         2020-06-15 15:21:03-05:00         10
# CRESD678FRBCLE 2016-05-06 14:23:01-05:00          2
# RRESD678FRBCLE 2016-05-06 14:22:15-05:00          1
#
#                                                             notes
# series id
# DGS10           For further information regarding treasury con...
# GS10            Averages of business days. For further informa...
# WGS10YR         Averages of business days. For further informa...
# DGS1            For further information regarding treasury con...
# GS1             Averages of business days. For further informa...
# WGS1YR          Averages of business days. For further informa...
# DGS30           Yields on actively traded non-inflation-indexe...
# DGS5            For further information regarding treasury con...
# GS5             Averages of business days. For further informa...
# GS30            Yields on actively traded non-inflation-indexe...
# WGS5YR          Averages of business days. For further informa...
# DGS2            For further information regarding treasury con...
# DGS3MO          For further information regarding treasury con...
# WGS30YR         Yields on actively traded non-inflation-indexe...
# GS3M            Averages of business days. For further informa...
# GS2             Averages of business days. For further informa...
# WGS2YR          Averages of business days. For further informa...
# WGS3MO          Averages of business days. For further informa...
# DGS20           For further information regarding treasury con...
# GS20            Averages of business days. For information on ...
# DGS1MO          For further information regarding treasury con...
# DGS3            For further information regarding treasury con...
# GS3             Averages of business days. For further informa...
# GS1M            Averages of business days. For further informa...
# WGS20YR         Averages of business days. For further informa...
# WGS3YR          Averages of business days. For further informa...
# WGS1MO          Averages of business days. For further informa...
# DGS7            For further information regarding treasury con...
# GS7             Averages of business days. For further informa...
# WGS7YR          Averages of business days. For further informa...
# DGS6MO          For further information regarding treasury con...
# GS6M            Averages of business days. For further informa...
# WGS6MO          Averages of business days. For further informa...
# CRESD678FRBCLE  In May of 2016, the source discovered errors i...
# RRESD678FRBCLE  In May of 2016, the source discovered errors i...

# %%
risk_free=fred.get_series('GS3M')
risk_free=risk_free['2016-01-01':'2019-12-31']
rf=risk_free.pct_change()

# %%
plt.plot(risk_free)
plt.xlabel('Date')
plt.ylabel('%')
plt.title('3-Month Treasury Constant Maturity Rate')
plt.tight_layout()

plt.show()

# %% [markdown]
# To calculate the excess return, we need to subtract risk free rate from the stock returns. We calculate and stor all excess return in data frame named `returns`.

# %%
stocks=["CMCSA","T","VZ","GSPC"]
for i in stocks:
    returns["excess_return_"+str(i)]=returns[i]-rf

# %%
returns.head()
# Out:
#                CMCSA         T        VZ      GSPC  excess_return_CMCSA  \
# Date
# 2016-02-01  0.036266  0.024681  0.015209 -0.004128            -0.156042
# 2016-03-01  0.058212  0.060081  0.066036  0.065991             0.090470
# 2016-04-01 -0.005239 -0.008935 -0.058062  0.002699             0.228094
# 2016-05-01  0.041804  0.008501 -0.000785  0.015325            -0.175587
# 2016-06-01  0.030016  0.103704  0.097053  0.000911             0.065730
#
#             excess_return_T  excess_return_VZ  excess_return_GSPC
# Date
# 2016-02-01        -0.167627         -0.177099           -0.196436
# 2016-03-01         0.092339          0.098294            0.098249
# 2016-04-01         0.224398          0.175271            0.236033
# 2016-05-01        -0.208891         -0.218177           -0.202067
# 2016-06-01         0.139418          0.132767            0.036625

# %% [markdown]
# We are ready to run the CAPM analysis after all these preparation process. First, we run the CAPM analysis for Comcast and it turns out that Comcast is less volatile than the S&P-500 as we have a beta coefficient of 0.8944. This estimated beta coefficient is statistically significant at 1% level since we have a t-value of 15.164 (or p-value of 0.0000). However, the intercept term is not statistically significant. Therefore, interpretation of the intercept term, which indicates the performance of the technical analysis, does not make sense.

# %%
import statsmodels.api as sm

# %%
y_cmsa=returns['excess_return_CMCSA']
X=returns['excess_return_GSPC']

# %%
X= sm.add_constant(X, prepend=False)
CAPM_CMSA= sm.OLS(y_cmsa, X)
CAPM_results_CMSA = CAPM_CMSA.fit()

# %%
CAPM_results_CMSA.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     excess_return_CMCSA   R-squared:                       0.836
# Model:                             OLS   Adj. R-squared:                  0.833
# Method:                  Least Squares   F-statistic:                     230.0
# Date:                 Mon, 22 Jun 2020   Prob (F-statistic):           2.65e-19
# Time:                         20:13:17   Log-Likelihood:                 76.538
# No. Observations:                   47   AIC:                            -149.1
# Df Residuals:                       45   BIC:                            -145.4
# Df Model:                            1
# Covariance Type:             nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# excess_return_GSPC     0.9350      0.062     15.164      0.000       0.811       1.059
# const                 -0.0017      0.007     -0.226      0.822      -0.016       0.013
# ==============================================================================
# Omnibus:                        1.609   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.447   Jarque-Bera (JB):                0.787
# Skew:                           0.023   Prob(JB):                        0.675
# Kurtosis:                       3.632   Cond. No.                         8.72
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# When it comes to AT&T, the result is quite similar in terms of slope coefficien $\beta$ and intercept term. The beta coefficient of 0.9781 implies that there is a correlation between excess market return and excess return of the AT&T. More specifically, 1-unit increase in S&P-500 leads to an increase in AT&T return by nearly 0.97. Again, the intercept term is not statistically significant at conventional confidence interval.

# %%
y_T=returns['excess_return_T']

# %%
X = sm.add_constant(X, prepend=False)
CAPM_T= sm.OLS(y_T, X)
CAPM_results_T = CAPM_T.fit()

# %%
CAPM_results_T.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        excess_return_T   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     259.2
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.72e-20
# Time:                        20:13:20   Log-Likelihood:                 77.232
# No. Observations:                  47   AIC:                            -150.5
# Df Residuals:                      45   BIC:                            -146.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# excess_return_GSPC     0.9781      0.061     16.098      0.000       0.856       1.100
# const                 -0.0091      0.007     -1.255      0.216      -0.024       0.006
# ==============================================================================
# Omnibus:                        5.934   Durbin-Watson:                   2.339
# Prob(Omnibus):                  0.051   Jarque-Bera (JB):                5.507
# Skew:                          -0.489   Prob(JB):                       0.0637
# Kurtosis:                       4.363   Cond. No.                         8.72
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Verizon does tell us a similar story with positive and statistically significant beta coefficient and statistically insignificant intercept term. The magnitude of beta coefficient is 0.9345 indicating that 1-unit increase in S&P-500 results in an increase of 0.93 in Verizon return.

# %%
y_VZ=returns['excess_return_VZ']

# %%
X = sm.add_constant(X, prepend=False)
CAPM_VZ= sm.OLS(y_VZ, X)
CAPM_results_VZ = CAPM_VZ.fit()

# %%
CAPM_results_VZ.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       excess_return_VZ   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     219.4
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           6.42e-19
# Time:                        20:13:23   Log-Likelihood:                 75.463
# No. Observations:                  47   AIC:                            -146.9
# Df Residuals:                      45   BIC:                            -143.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# excess_return_GSPC     0.9345      0.063     14.813      0.000       0.807       1.062
# const                 -0.0080      0.008     -1.066      0.292      -0.023       0.007
# ==============================================================================
# Omnibus:                        2.199   Durbin-Watson:                   2.318
# Prob(Omnibus):                  0.333   Jarque-Bera (JB):                1.457
# Skew:                           0.417   Prob(JB):                        0.483
# Kurtosis:                       3.220   Cond. No.                         8.72
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CAPM_results_VZ.params[0]
# Out:
# 0.9344985589626482

# %% [markdown]
# In summary, considering the estimated beta coefficients, the most and least responsive or volatile stock is AT&T and Verizon, respectively.

# %% [markdown]
# As a final note, I would like to name a few pros and cons of CAPM approach:

# %% [markdown]
# **Pros**

# %% [markdown]
# * Ease of use
#
# * Diversified Portfolio: The assumption that investors have a diversified portfolio similar to the market portfolio eliminates the non-systematic (specific) risk.
#
# * CAPM takes into account systematic risk
#
# * CAPM can be used as a model to account for the business and financial Risk variability

# %% [markdown]
# **Cons**

# %% [markdown]
# * The proxy used for risk free rate  is subject to change and open to discussion.
# * A risk-free borrowing capability is far from being realistic
# * Using CAPM to evaluate an investment must find a suitable beta for the project or investment to correctly evaluate it.

# %% [markdown]
# # <font color=blue> 2. Arbitrage Pricing Theorem (APT) </font>

# %% [markdown]
# Despite all merits that CAPM has, it is not free from critism some of which are listed above. Stephen Ross 1976 attempted to address these critics and propose `Arbitrage Pricing Theorem` (APT), which is based on the identifying various systematic risk factors, which is rather appealing in that it is not realistic to assume that single systematic risk factor affects stock returns. However, inclusion of sources of macroeconomic variable can provide us a better understanding about the stock returns. So, the main goal of APT is to improve portfolio performance by better understanding portfolio creation and evaluation.

# %% [markdown]
# The Arbitrage Pricing Model was proposed by Stephen Ross and predicts the relationship between the return of the portfolio and the return of a single asset through several independent macroeconomic variables. The APT has following assumptions (Bodie et al.(2008)):

# %% [markdown]
# * Security returns can be described by a factor model;
# * There are sufficient securities to diversify away idiosyncratic risk; and
# * Well-functioning security markets do not allow for the persistence of arbitrage opportunities.

# %% [markdown]
# We can generalize the APT model as follows:

# %% [markdown]
# $$\begin{equation}
# r_i- r_f = \alpha_i + \beta_{im}(r_m-r_f) +...+ \beta_{ij}(r_j-r_f)  + \epsilon_i
# \end{equation}$$

# %% [markdown]
# where
#  * $r_i$: Expected return of the $i^{th}$ stock
#  * $\alpha_i$: asset’s return coming from technical analysis
#  * $r_m$ and $r_j$: common risk factors
#  * $a_{im}$: systematic factor of $m^{th}$ factor
#  * $\epsilon_i$: Error term

# %% [markdown]
# Now, the question is how do we find the proper macroeconomic factors? We are looking for some important risk factor that raise the concern of the investors.

# %% [markdown]
# [Chen, Roll and Ross (1986)]('https://pdfs.semanticscholar.org/08d9/21ea5c119ea770194bce73f726adf5614daa.pdf?_ga=2.9307062.284215294.1589479012-1597751336.1589479012') address this issue by listing following variables:

# %% [markdown]
# * Inflation rate
# * Growth rate in industrial production
# * Term structure
# * Spread between high-grade and low-grade bond
# * Real interest rate
# * Oil prices

# %% [markdown]
# Having listed some relevant variables, we are now able to run the APT analysis. We could proceed by retrieving the data first. Again, we refer to the relate APIs to extract these data. Thanks to `Yahoo Finance` and `FRED`, we have stock prices, risk free rate, and stock market index (S&P-500) from the preceding part.

# %% [markdown]
# Following the finding of Chen, Roll and Ross (1986),  `industrial production`, `changes in inflation`, `stock market index` will be our independent variables as they have appeared to explain a significant portion of the time-series variability of stock returns.

# %% [markdown]
# At this point, to extract the macroeconomic variable, `FRED API` is a convenient database:

# %%
from fredapi import Fred
fred = Fred(api_key='78b14ec6ba46f484b94db43694468bb1')

# %%
fred.search('industrial')
# Out:
#                               id realtime_start realtime_end  \
# series id
# INDPRO                    INDPRO     2020-06-22   2020-06-22
# IPMAN                      IPMAN     2020-06-22   2020-06-22
# IPGMFN                    IPGMFN     2020-06-22   2020-06-22
# DJIA                        DJIA     2020-06-22   2020-06-22
# BUSLOANS                BUSLOANS     2020-06-22   2020-06-22
# ...                          ...            ...          ...
# NLDPROINDQISMEI  NLDPROINDQISMEI     2020-06-22   2020-06-22
# MAMANNGSP              MAMANNGSP     2020-06-22   2020-06-22
# A34HNO                    A34HNO     2020-06-22   2020-06-22
# NLDPROINDAISMEI  NLDPROINDAISMEI     2020-06-22   2020-06-22
# VTMANNGSP              VTMANNGSP     2020-06-22   2020-06-22
#
#                                                              title  \
# series id
# INDPRO                                 Industrial Production Index
# IPMAN                 Industrial Production: Manufacturing (NAICS)
# IPGMFN                Industrial Production: Manufacturing (NAICS)
# DJIA                                  Dow Jones Industrial Average
# BUSLOANS         Commercial and Industrial Loans, All Commercia...
# ...                                                            ...
# NLDPROINDQISMEI        Production of Total Industry in Netherlands
# MAMANNGSP        Gross Domestic Product by Industry: Private In...
# A34HNO           Value of Manufacturers' New Orders for Durable...
# NLDPROINDAISMEI        Production of Total Industry in Netherlands
# VTMANNGSP        Gross Domestic Product by Industry: Private In...
#
#                 observation_start observation_end  frequency frequency_short  \
# series id
# INDPRO                 1919-01-01      2020-05-01    Monthly               M
# IPMAN                  1972-01-01      2020-05-01    Monthly               M
# IPGMFN                 1972-01-01      2020-05-01    Monthly               M
# DJIA                   2010-06-21      2020-06-19      Daily               D
# BUSLOANS               1947-01-01      2020-05-01    Monthly               M
# ...                           ...             ...        ...             ...
# NLDPROINDQISMEI        1960-01-01      2020-01-01  Quarterly               Q
# MAMANNGSP              1997-01-01      2019-01-01     Annual               A
# A34HNO                 1992-02-01      2020-04-01    Monthly               M
# NLDPROINDAISMEI        1960-01-01      2019-01-01     Annual               A
# VTMANNGSP              1997-01-01      2019-01-01     Annual               A
#
#                                     units     units_short  \
# series id
# INDPRO                     Index 2012=100  Index 2012=100
# IPMAN                      Index 2012=100  Index 2012=100
# IPGMFN                     Index 2012=100  Index 2012=100
# DJIA                                Index           Index
# BUSLOANS         Billions of U.S. Dollars  Bil. of U.S. $
# ...                                   ...             ...
# NLDPROINDQISMEI            Index 2015=100  Index 2015=100
# MAMANNGSP             Millions of Dollars       Mil. of $
# A34HNO                 Million of Dollars       Mil. of $
# NLDPROINDAISMEI            Index 2015=100  Index 2015=100
# VTMANNGSP             Millions of Dollars       Mil. of $
#
#                      seasonal_adjustment seasonal_adjustment_short  \
# series id
# INDPRO               Seasonally Adjusted                        SA
# IPMAN                Seasonally Adjusted                        SA
# IPGMFN           Not Seasonally Adjusted                       NSA
# DJIA             Not Seasonally Adjusted                       NSA
# BUSLOANS             Seasonally Adjusted                        SA
# ...                                  ...                       ...
# NLDPROINDQISMEI      Seasonally Adjusted                        SA
# MAMANNGSP        Not Seasonally Adjusted                       NSA
# A34HNO               Seasonally Adjusted                        SA
# NLDPROINDAISMEI  Not Seasonally Adjusted                       NSA
# VTMANNGSP        Not Seasonally Adjusted                       NSA
#
#                               last_updated popularity  \
# series id
# INDPRO           2020-06-16 08:24:02-05:00         88
# IPMAN            2020-06-16 08:25:34-05:00         65
# IPGMFN           2020-06-16 08:25:40-05:00         30
# DJIA             2020-06-19 19:01:03-05:00         79
# BUSLOANS         2020-06-19 15:48:16-05:00         75
# ...                                    ...        ...
# NLDPROINDQISMEI  2020-06-12 09:52:33-05:00          2
# MAMANNGSP        2020-04-07 17:03:26-05:00          2
# A34HNO           2020-06-03 09:01:10-05:00         15
# NLDPROINDAISMEI  2020-05-14 17:20:41-05:00          1
# VTMANNGSP        2020-04-07 17:02:36-05:00          1
#
#                                                              notes
# series id
# INDPRO           The Industrial Production Index (INDPRO) is an...
# IPMAN                                                         None
# IPGMFN           The industrial production (IP) index measures ...
# DJIA             The observations for the Dow Jones Industrial ...
# BUSLOANS         For further information, please refer to the B...
# ...                                                            ...
# NLDPROINDQISMEI  Copyright, 2016, OECD. Reprinted with permissi...
# MAMANNGSP        For more information about this release go to ...
# A34HNO                                                        None
# NLDPROINDAISMEI  Copyright, 2016, OECD. Reprinted with permissi...
# VTMANNGSP        For more information about this release go to ...
#
# [1000 rows x 15 columns]

# %%
ind=fred.get_series('INDPRO')
ind=ind['2016-01-01':'2019-12-31']

# %% [markdown]
# To be consistent, I drop the first observation in industrial production index as we calculate return from stock prices, first month is dropped. Besides, to deal with the scaling issue, I take the logarithm of the data:

# %%
ind.head()
# Out:
# 2016-01-01    102.9525
# 2016-02-01    102.2225
# 2016-03-01    101.4155
# 2016-04-01    101.5167
# 2016-05-01    101.4298
# dtype: float64

# %%
log_ind=np.log(ind.iloc[1:])

# %%
fred.search('potential inflation')
# Out:
#                         id realtime_start realtime_end  \
# series id
# CPIEHOUSE        CPIEHOUSE     2020-06-22   2020-06-22
# CPIEALL            CPIEALL     2020-06-22   2020-06-22
# CPIEMEDCARE    CPIEMEDCARE     2020-06-22   2020-06-22
# CPIEBEV            CPIEBEV     2020-06-22   2020-06-22
# CPIETRANS        CPIETRANS     2020-06-22   2020-06-22
# CPIEAPPAREL    CPIEAPPAREL     2020-06-22   2020-06-22
# CPIECOMEDU      CPIECOMEDU     2020-06-22   2020-06-22
# CPIEOTRGS        CPIEOTRGS     2020-06-22   2020-06-22
# GDPPOT              GDPPOT     2020-06-22   2020-06-22
# NROU                  NROU     2020-06-22   2020-06-22
# NROUST              NROUST     2020-06-22   2020-06-22
# FEDTARMDLR      FEDTARMDLR     2020-06-22   2020-06-22
# GDPC1CTMLR      GDPC1CTMLR     2020-06-22   2020-06-22
# UNRATECTMLR    UNRATECTMLR     2020-06-22   2020-06-22
# GDPC1MDLR        GDPC1MDLR     2020-06-22   2020-06-22
# PCECTPICTMLR  PCECTPICTMLR     2020-06-22   2020-06-22
# UNRATEMDLR      UNRATEMDLR     2020-06-22   2020-06-22
# GDPC1RHLR        GDPC1RHLR     2020-06-22   2020-06-22
# FEDTARCTLLR    FEDTARCTLLR     2020-06-22   2020-06-22
# GDPC1RMLR        GDPC1RMLR     2020-06-22   2020-06-22
# FEDTARRMLR      FEDTARRMLR     2020-06-22   2020-06-22
# FEDTARCTMLR    FEDTARCTMLR     2020-06-22   2020-06-22
# PCECTPIMDLR    PCECTPIMDLR     2020-06-22   2020-06-22
# PCECTPIRMLR    PCECTPIRMLR     2020-06-22   2020-06-22
# PCECTPIRLLR    PCECTPIRLLR     2020-06-22   2020-06-22
# GDPC1CTHLR      GDPC1CTHLR     2020-06-22   2020-06-22
# PCECTPIRHLR    PCECTPIRHLR     2020-06-22   2020-06-22
# PCECTPICTLLR  PCECTPICTLLR     2020-06-22   2020-06-22
# FEDTARCTHLR    FEDTARCTHLR     2020-06-22   2020-06-22
# FEDTARRLLR      FEDTARRLLR     2020-06-22   2020-06-22
# UNRATERMLR      UNRATERMLR     2020-06-22   2020-06-22
# FEDTARRHLR      FEDTARRHLR     2020-06-22   2020-06-22
# GDPC1RLLR        GDPC1RLLR     2020-06-22   2020-06-22
# GDPC1CTLLR      GDPC1CTLLR     2020-06-22   2020-06-22
# PCECTPICTHLR  PCECTPICTHLR     2020-06-22   2020-06-22
# UNRATERHLR      UNRATERHLR     2020-06-22   2020-06-22
# UNRATECTHLR    UNRATECTHLR     2020-06-22   2020-06-22
# UNRATERLLR      UNRATERLLR     2020-06-22   2020-06-22
# UNRATECTLLR    UNRATECTLLR     2020-06-22   2020-06-22
#
#                                                           title  \
# series id
# CPIEHOUSE            Experimental Consumer Price Index: Housing
# CPIEALL            Experimental Consumer Price Index: All Items
# CPIEMEDCARE     Experimental Consumer Price Index: Medical Care
# CPIEBEV       Experimental Consumer Price Index: Food and Be...
# CPIETRANS     Experimental Consumer Price Index: Transportation
# CPIEAPPAREL          Experimental Consumer Price Index: Apparel
# CPIECOMEDU    Experimental Consumer Price Index: Education a...
# CPIEOTRGS     Experimental Consumer Price Index: Other Goods...
# GDPPOT                    Real Potential Gross Domestic Product
# NROU                   Natural Rate of Unemployment (Long-Term)
# NROUST                Natural Rate of Unemployment (Short-Term)
# FEDTARMDLR    Longer Run FOMC Summary of Economic Projection...
# GDPC1CTMLR    Longer Run FOMC Summary of Economic Projection...
# UNRATECTMLR   Longer Run FOMC Summary of Economic Projection...
# GDPC1MDLR     Longer Run FOMC Summary of Economic Projection...
# PCECTPICTMLR  Longer Run FOMC Summary of Economic Projection...
# UNRATEMDLR    Longer Run FOMC Summary of Economic Projection...
# GDPC1RHLR     Longer Run FOMC Summary of Economic Projection...
# FEDTARCTLLR   Longer Run FOMC Summary of Economic Projection...
# GDPC1RMLR     Longer Run FOMC Summary of Economic Projection...
# FEDTARRMLR    Longer Run FOMC Summary of Economic Projection...
# FEDTARCTMLR   Longer Run FOMC Summary of Economic Projection...
# PCECTPIMDLR   Longer Run FOMC Summary of Economic Projection...
# PCECTPIRMLR   Longer Run FOMC Summary of Economic Projection...
# PCECTPIRLLR   Longer Run FOMC Summary of Economic Projection...
# GDPC1CTHLR    Longer Run FOMC Summary of Economic Projection...
# PCECTPIRHLR   Longer Run FOMC Summary of Economic Projection...
# PCECTPICTLLR  Longer Run FOMC Summary of Economic Projection...
# FEDTARCTHLR   Longer Run FOMC Summary of Economic Projection...
# FEDTARRLLR    Longer Run FOMC Summary of Economic Projection...
# UNRATERMLR    Longer Run FOMC Summary of Economic Projection...
# FEDTARRHLR    Longer Run FOMC Summary of Economic Projection...
# GDPC1RLLR     Longer Run FOMC Summary of Economic Projection...
# GDPC1CTLLR    Longer Run FOMC Summary of Economic Projection...
# PCECTPICTHLR  Longer Run FOMC Summary of Economic Projection...
# UNRATERHLR    Longer Run FOMC Summary of Economic Projection...
# UNRATECTHLR   Longer Run FOMC Summary of Economic Projection...
# UNRATERLLR    Longer Run FOMC Summary of Economic Projection...
# UNRATECTLLR   Longer Run FOMC Summary of Economic Projection...
#
#              observation_start observation_end       frequency  \
# series id
# CPIEHOUSE           1982-12-01      2020-05-01         Monthly
# CPIEALL             1982-12-01      2020-05-01         Monthly
# CPIEMEDCARE         1982-12-01      2020-05-01         Monthly
# CPIEBEV             1982-12-01      2020-05-01         Monthly
# CPIETRANS           1982-12-01      2020-05-01         Monthly
# CPIEAPPAREL         1982-12-01      2020-05-01         Monthly
# CPIECOMEDU          1993-01-01      2020-05-01         Monthly
# CPIEOTRGS           1982-12-01      2020-05-01         Monthly
# GDPPOT              1949-01-01      2030-10-01       Quarterly
# NROU                1949-01-01      2030-10-01       Quarterly
# NROUST              1949-01-01      2030-10-01       Quarterly
# FEDTARMDLR          2012-01-25      2020-06-10  Not Applicable
# GDPC1CTMLR          2009-02-18      2020-06-10  Not Applicable
# UNRATECTMLR         2009-02-18      2020-06-10  Not Applicable
# GDPC1MDLR           2015-06-17      2020-06-10  Not Applicable
# PCECTPICTMLR        2009-02-18      2020-06-10  Not Applicable
# UNRATEMDLR          2015-06-17      2020-06-10  Not Applicable
# GDPC1RHLR           2009-02-18      2020-06-10  Not Applicable
# FEDTARCTLLR         2015-06-17      2020-06-10  Not Applicable
# GDPC1RMLR           2009-02-18      2020-06-10  Not Applicable
# FEDTARRMLR          2015-06-17      2020-06-10  Not Applicable
# FEDTARCTMLR         2015-06-17      2020-06-10  Not Applicable
# PCECTPIMDLR         2015-06-17      2020-06-10  Not Applicable
# PCECTPIRMLR         2009-02-18      2020-06-10  Not Applicable
# PCECTPIRLLR         2009-02-18      2020-06-10  Not Applicable
# GDPC1CTHLR          2009-02-18      2020-06-10  Not Applicable
# PCECTPIRHLR         2009-02-18      2020-06-10  Not Applicable
# PCECTPICTLLR        2009-02-18      2020-06-10  Not Applicable
# FEDTARCTHLR         2015-06-17      2020-06-10  Not Applicable
# FEDTARRLLR          2015-06-17      2020-06-10  Not Applicable
# UNRATERMLR          2009-02-18      2020-06-10  Not Applicable
# FEDTARRHLR          2015-06-17      2020-06-10  Not Applicable
# GDPC1RLLR           2009-02-18      2020-06-10  Not Applicable
# GDPC1CTLLR          2009-02-18      2020-06-10  Not Applicable
# PCECTPICTHLR        2009-02-18      2020-06-10  Not Applicable
# UNRATERHLR          2009-02-18      2020-06-10  Not Applicable
# UNRATECTHLR         2009-02-18      2020-06-10  Not Applicable
# UNRATERLLR          2009-02-18      2020-06-10  Not Applicable
# UNRATECTLLR         2009-02-18      2020-06-10  Not Applicable
#
#              frequency_short                                            units  \
# series id
# CPIEHOUSE                  M                                   Index 1982=100
# CPIEALL                    M                                   Index 1982=100
# CPIEMEDCARE                M                                   Index 1982=100
# CPIEBEV                    M                                   Index 1982=100
# CPIETRANS                  M                                   Index 1982=100
# CPIEAPPAREL                M                                   Index 1982=100
# CPIECOMEDU                 M                                   Index 1982=100
# CPIEOTRGS                  M                                   Index 1982=100
# GDPPOT                     Q                 Billions of Chained 2012 Dollars
# NROU                       Q                                          Percent
# NROUST                     Q                                          Percent
# FEDTARMDLR                NA                                          Percent
# GDPC1CTMLR                NA  Fourth Quarter to Fourth Quarter Percent Change
# UNRATECTMLR               NA                          Fourth Quarter, Percent
# GDPC1MDLR                 NA  Fourth Quarter to Fourth Quarter Percent Change
# PCECTPICTMLR              NA  Fourth Quarter to Fourth Quarter Percent Change
# UNRATEMDLR                NA                                          Percent
# GDPC1RHLR                 NA  Fourth Quarter to Fourth Quarter Percent Change
# FEDTARCTLLR               NA                                          Percent
# GDPC1RMLR                 NA  Fourth Quarter to Fourth Quarter Percent Change
# FEDTARRMLR                NA                                          Percent
# FEDTARCTMLR               NA                                          Percent
# PCECTPIMDLR               NA  Fourth Quarter to Fourth Quarter Percent Change
# PCECTPIRMLR               NA  Fourth Quarter to Fourth Quarter Percent Change
# PCECTPIRLLR               NA  Fourth Quarter to Fourth Quarter Percent Change
# GDPC1CTHLR                NA  Fourth Quarter to Fourth Quarter Percent Change
# PCECTPIRHLR               NA  Fourth Quarter to Fourth Quarter Percent Change
# PCECTPICTLLR              NA  Fourth Quarter to Fourth Quarter Percent Change
# FEDTARCTHLR               NA                                          Percent
# FEDTARRLLR                NA                                          Percent
# UNRATERMLR                NA                          Fourth Quarter, Percent
# FEDTARRHLR                NA                                          Percent
# GDPC1RLLR                 NA  Fourth Quarter to Fourth Quarter Percent Change
# GDPC1CTLLR                NA  Fourth Quarter to Fourth Quarter Percent Change
# PCECTPICTHLR              NA  Fourth Quarter to Fourth Quarter Percent Change
# UNRATERHLR                NA                          Fourth Quarter, Percent
# UNRATECTHLR               NA                          Fourth Quarter, Percent
# UNRATERLLR                NA                          Fourth Quarter, Percent
# UNRATECTLLR               NA                          Fourth Quarter, Percent
#
#                                     units_short      seasonal_adjustment  \
# series id
# CPIEHOUSE                        Index 1982=100      Seasonally Adjusted
# CPIEALL                          Index 1982=100      Seasonally Adjusted
# CPIEMEDCARE                      Index 1982=100      Seasonally Adjusted
# CPIEBEV                          Index 1982=100      Seasonally Adjusted
# CPIETRANS                        Index 1982=100      Seasonally Adjusted
# CPIEAPPAREL                      Index 1982=100      Seasonally Adjusted
# CPIECOMEDU                       Index 1982=100      Seasonally Adjusted
# CPIEOTRGS                        Index 1982=100      Seasonally Adjusted
# GDPPOT                      Bil. of Chn. 2012 $  Not Seasonally Adjusted
# NROU                                          %  Not Seasonally Adjusted
# NROUST                                        %  Not Seasonally Adjusted
# FEDTARMDLR                                    %  Not Seasonally Adjusted
# GDPC1CTMLR    Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# UNRATECTMLR                      Fourth Qtr., %  Not Seasonally Adjusted
# GDPC1MDLR     Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# PCECTPICTMLR  Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# UNRATEMDLR                                    %  Not Seasonally Adjusted
# GDPC1RHLR     Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# FEDTARCTLLR                                   %  Not Seasonally Adjusted
# GDPC1RMLR     Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# FEDTARRMLR                                    %  Not Seasonally Adjusted
# FEDTARCTMLR                                   %  Not Seasonally Adjusted
# PCECTPIMDLR   Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# PCECTPIRMLR   Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# PCECTPIRLLR   Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# GDPC1CTHLR    Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# PCECTPIRHLR   Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# PCECTPICTLLR  Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# FEDTARCTHLR                                   %  Not Seasonally Adjusted
# FEDTARRLLR                                    %  Not Seasonally Adjusted
# UNRATERMLR                       Fourth Qtr., %  Not Seasonally Adjusted
# FEDTARRHLR                                    %  Not Seasonally Adjusted
# GDPC1RLLR     Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# GDPC1CTLLR    Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# PCECTPICTHLR  Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# UNRATERHLR                       Fourth Qtr., %  Not Seasonally Adjusted
# UNRATECTHLR                      Fourth Qtr., %  Not Seasonally Adjusted
# UNRATERLLR                       Fourth Qtr., %  Not Seasonally Adjusted
# UNRATECTLLR                      Fourth Qtr., %  Not Seasonally Adjusted
#
#              seasonal_adjustment_short               last_updated popularity  \
# series id
# CPIEHOUSE                           SA  2020-06-10 10:07:02-05:00          8
# CPIEALL                             SA  2020-06-10 10:07:01-05:00          7
# CPIEMEDCARE                         SA  2020-06-10 10:07:02-05:00          4
# CPIEBEV                             SA  2020-06-10 10:07:02-05:00          4
# CPIETRANS                           SA  2020-06-10 10:07:02-05:00          3
# CPIEAPPAREL                         SA  2020-06-10 10:07:02-05:00          3
# CPIECOMEDU                          SA  2020-06-10 10:07:02-05:00          2
# CPIEOTRGS                           SA  2020-06-10 10:07:02-05:00          1
# GDPPOT                             NSA  2020-02-07 14:49:01-06:00         75
# NROU                               NSA  2020-02-07 14:49:11-06:00         71
# NROUST                             NSA  2020-02-07 14:49:14-06:00         61
# FEDTARMDLR                         NSA  2020-06-10 16:17:18-05:00         29
# GDPC1CTMLR                         NSA  2020-06-10 16:17:12-05:00         21
# UNRATECTMLR                        NSA  2020-06-10 16:17:14-05:00         19
# GDPC1MDLR                          NSA  2020-06-10 16:17:18-05:00          9
# PCECTPICTMLR                       NSA  2020-06-10 16:17:17-05:00          7
# UNRATEMDLR                         NSA  2020-06-10 16:17:17-05:00          6
# GDPC1RHLR                          NSA  2020-06-10 16:17:15-05:00          6
# FEDTARCTLLR                        NSA  2020-06-10 16:17:18-05:00          4
# GDPC1RMLR                          NSA  2020-06-10 16:17:15-05:00          4
# FEDTARRMLR                         NSA  2020-06-10 16:17:16-05:00          4
# FEDTARCTMLR                        NSA  2020-06-10 16:17:16-05:00          4
# PCECTPIMDLR                        NSA  2020-06-10 16:17:17-05:00          3
# PCECTPIRMLR                        NSA  2020-06-10 16:17:15-05:00          3
# PCECTPIRLLR                        NSA  2020-06-10 16:17:15-05:00          3
# GDPC1CTHLR                         NSA  2020-06-10 16:17:17-05:00          3
# PCECTPIRHLR                        NSA  2020-06-10 16:17:17-05:00          2
# PCECTPICTLLR                       NSA  2020-06-10 16:17:17-05:00          2
# FEDTARCTHLR                        NSA  2020-06-10 16:17:17-05:00          2
# FEDTARRLLR                         NSA  2020-06-10 16:17:16-05:00          2
# UNRATERMLR                         NSA  2020-06-10 16:17:15-05:00          2
# FEDTARRHLR                         NSA  2020-06-10 16:17:17-05:00          2
# GDPC1RLLR                          NSA  2020-06-10 16:17:17-05:00          2
# GDPC1CTLLR                         NSA  2020-06-10 16:17:16-05:00          2
# PCECTPICTHLR                       NSA  2020-06-10 16:17:17-05:00          1
# UNRATERHLR                         NSA  2020-06-10 16:17:17-05:00          1
# UNRATECTHLR                        NSA  2020-06-10 16:17:17-05:00          1
# UNRATERLLR                         NSA  2020-06-10 16:17:17-05:00          1
# UNRATECTLLR                        NSA  2020-06-10 16:17:17-05:00          1
#
#                                                           notes
# series id
# CPIEHOUSE     There are several limitations in the experimen...
# CPIEALL       There are several limitations in the experimen...
# CPIEMEDCARE   There are several limitations in the experimen...
# CPIEBEV       There are several limitations in the experimen...
# CPIETRANS     There are several limitations in the experimen...
# CPIEAPPAREL   There are several limitations in the experimen...
# CPIECOMEDU    There are several limitations in the experimen...
# CPIEOTRGS     There are several limitations in the experimen...
# GDPPOT        Real potential GDP is the CBO’s estimate of th...
# NROU          The natural rate of unemployment (NAIRU) is th...
# NROUST        The natural rate of unemployment (NAIRU) is th...
# FEDTARMDLR    The longer-run projections are the rates of gr...
# GDPC1CTMLR    The longer-run projections are the rates of gr...
# UNRATECTMLR   The longer-run projections are the rates of gr...
# GDPC1MDLR     The longer-run projections are the rates of gr...
# PCECTPICTMLR  The longer-run projections are the rates of gr...
# UNRATEMDLR    The longer-run projections are the rates of gr...
# GDPC1RHLR     The longer-run projections are the rates of gr...
# FEDTARCTLLR   The longer-run projections are the rates of gr...
# GDPC1RMLR     The longer-run projections are the rates of gr...
# FEDTARRMLR    The longer-run projections are the rates of gr...
# FEDTARCTMLR   The longer-run projections are the rates of gr...
# PCECTPIMDLR   The longer-run projections are the rates of gr...
# PCECTPIRMLR   The longer-run projections are the rates of gr...
# PCECTPIRLLR   The longer-run projections are the rates of gr...
# GDPC1CTHLR    The longer-run projections are the rates of gr...
# PCECTPIRHLR   The longer-run projections are the rates of gr...
# PCECTPICTLLR  The longer-run projections are the rates of gr...
# FEDTARCTHLR   The longer-run projections are the rates of gr...
# FEDTARRLLR    The longer-run projections are the rates of gr...
# UNRATERMLR    The longer-run projections are the rates of gr...
# FEDTARRHLR    The longer-run projections are the rates of gr...
# GDPC1RLLR     The longer-run projections are the rates of gr...
# GDPC1CTLLR    The longer-run projections are the rates of gr...
# PCECTPICTHLR  The longer-run projections are the rates of gr...
# UNRATERHLR    The longer-run projections are the rates of gr...
# UNRATECTHLR   The longer-run projections are the rates of gr...
# UNRATERLLR    The longer-run projections are the rates of gr...
# UNRATECTLLR   The longer-run projections are the rates of gr...

# %%
inf=fred.get_series('CPIEALL')
inf=inf['2016-01-01':'2019-12-31']

# %%
inf_rate=inf.pct_change().dropna()

# %% [markdown]
# We have completed data collection process and now we should combine all these variables into single data frame along the columns. Pandas' `concat` function does this for us and create a single data frame:

# %%
df_comcast=pd.concat([returns.excess_return_CMCSA, inf_rate,log_ind,returns.excess_return_GSPC], axis=1)
df_comcast=df_comcast.rename({0:'inf_rate',1:'log_ind'}, axis='columns')

# %%
df_comcast.head()
# Out:
#             excess_return_CMCSA  inf_rate   log_ind  excess_return_GSPC
# 2016-02-01            -0.156042  0.001655  4.627152           -0.196436
# 2016-03-01             0.090470  0.003670  4.619226            0.098249
# 2016-04-01             0.228094  0.004124  4.620223            0.236033
# 2016-05-01            -0.175587  0.003946  4.619367           -0.202067
# 2016-06-01             0.065730  0.003416  4.623744            0.036625

# %% [markdown]
# As we did before, assigning new variable to dependent and independent variables faciliates the regression analysis. `excess_return_CMCSA` is our dependent variable and it is labeled as y by convention. The rest of the variables are independent variables and they are labeled as `X_cmcsa`:

# %%
y=df_comcast['excess_return_CMCSA']
X_cmsa=df_comcast.iloc[:,1:]

# %%
X_cmsa= sm.add_constant(X_cmsa, prepend=False)
APT_CMSA= sm.OLS(y, X_cmsa)
APT_results_CMSA = APT_CMSA.fit()

# %%
APT_results_CMSA.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     excess_return_CMCSA   R-squared:                       0.837
# Model:                             OLS   Adj. R-squared:                  0.825
# Method:                  Least Squares   F-statistic:                     73.35
# Date:                 Mon, 22 Jun 2020   Prob (F-statistic):           6.00e-17
# Time:                         20:13:43   Log-Likelihood:                 76.567
# No. Observations:                   47   AIC:                            -145.1
# Df Residuals:                       43   BIC:                            -137.7
# Df Model:                            3
# Covariance Type:             nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# inf_rate              -0.0142      4.239     -0.003      0.997      -8.563       8.535
# log_ind                0.0573      0.265      0.216      0.830      -0.477       0.592
# excess_return_GSPC     0.9308      0.070     13.373      0.000       0.790       1.071
# const                 -0.2691      1.240     -0.217      0.829      -2.769       2.231
# ==============================================================================
# Omnibus:                        1.420   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.492   Jarque-Bera (JB):                0.624
# Skew:                          -0.004   Prob(JB):                        0.732
# Kurtosis:                       3.564   Cond. No.                     2.81e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# The findings suggest that the only statistically significant variable is market index `excess_return_GSPC`, which has a coefficient of 0.9308 indicating a high correlation with dependent variable. Inflation rate and industrial production seem to have no explanatory power.

# %% [markdown]
# The same procedure is applied to `AT&T` and `Verizon` given below:

# %%
df_T=pd.concat([returns.excess_return_T, inf_rate,log_ind,returns.excess_return_GSPC], axis=1)
df_T=df_T.rename({0:'inf_rate',1:'log_ind'}, axis='columns')

# %%
y=df_T['excess_return_T']
X_T=df_T.iloc[:,1:]

# %%
X_T= sm.add_constant(X_T, prepend=False)
APT_T= sm.OLS(y, X_T)
APT_results_T = APT_T.fit()

# %%
APT_results_T.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        excess_return_T   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     83.53
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           5.71e-18
# Time:                        20:13:49   Log-Likelihood:                 77.470
# No. Observations:                  47   AIC:                            -146.9
# Df Residuals:                      43   BIC:                            -139.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# inf_rate              -1.9301      4.158     -0.464      0.645     -10.316       6.456
# log_ind                0.0794      0.260      0.305      0.762      -0.445       0.604
# excess_return_GSPC     0.9798      0.068     14.350      0.000       0.842       1.118
# const                 -0.3759      1.216     -0.309      0.759      -2.829       2.077
# ==============================================================================
# Omnibus:                        6.982   Durbin-Watson:                   2.367
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                7.495
# Skew:                          -0.500   Prob(JB):                       0.0236
# Kurtosis:                       4.681   Cond. No.                     2.81e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Similar to our findings in Comcast, we have single statistically significant variable,`excess_return_GSPC`. Its estimated coefficient is 0.9799 showing even higher correlation with dependent variable compared to Comcast case. However, inflation rate and industrial production are again not statisticall significant, so it makes no sense to interpret the estimated coefficients of these variables.

# %% [markdown]
# Lastly, we have the APT analysis for `Verizon`:

# %%
df_VZ=pd.concat([returns.excess_return_VZ, inf_rate,log_ind,returns.excess_return_GSPC], axis=1)
df_VZ=df_VZ.rename({0:'inf_rate',1:'log_ind'}, axis='columns')

# %%
y=df_VZ['excess_return_VZ']
X_VZ=df_VZ.iloc[:,1:]

# %%
X_VZ= sm.add_constant(X_VZ, prepend=False)
APT_VZ= sm.OLS(y, X_VZ)
APT_results_VZ = APT_VZ.fit()

# %%
APT_results_VZ.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       excess_return_VZ   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     79.95
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.27e-17
# Time:                        20:13:54   Log-Likelihood:                 78.116
# No. Observations:                  47   AIC:                            -148.2
# Df Residuals:                      43   BIC:                            -140.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# inf_rate              -6.9183      4.102     -1.687      0.099     -15.190       1.353
# log_ind                0.2358      0.256      0.919      0.363      -0.281       0.753
# excess_return_GSPC     0.9443      0.067     14.021      0.000       0.808       1.080
# const                 -1.0949      1.200     -0.913      0.366      -3.514       1.324
# ==============================================================================
# Omnibus:                        4.606   Durbin-Watson:                   2.507
# Prob(Omnibus):                  0.100   Jarque-Bera (JB):                3.468
# Skew:                           0.614   Prob(JB):                        0.177
# Kurtosis:                       3.513   Cond. No.                     2.81e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# The story here a bit different. `Inflation rate` has a p-value of 0.099 meaning that it is statistically significant at 10% level. In addition to that, we have another variable with p-value of 0.000, which is `excess_return_GSPC`. Thus, both inflation rate and excess_return_GSPC have explanatory power on excess returns of Verizon, which is our dependent variable in this case. To be more precise, the magnitude of inflation rate, -6.9187 , is negative implying that an increase in inflation rate results in a decrease in excess returns of Verizon by nearly 6.91. On the contrary, a raise in excess return of market index leads to an increase in excess returns of Verizon by approximately 0.94.

# %% [markdown]
# # Conclusion

# %% [markdown]
# CAPM and APT are two prominent models used for asset pricing. In this lesson, we learn how to apply and interpret these techniques in Python. The CAPM tells us the stock characteristics based on the market index and it is a vital sign in the investor's decision making process. APT, on the other hand, tries to unveil the stock return dynamic based on some macroeconomic factors so that we are able to identify which factor affects the stock return dynamic most.

# %% [markdown]
# **References**

# %% [markdown]
# * Bodie, Z., Kane, A., Marcus, A. J., & Mohanty, P. (2008). Investments (SIE). McGraw-Hill Education.

# %% [markdown]
# * [Shapiro](http://people.stern.nyu.edu/ashapiro/courses/B01.231103/FFL09.pdf) (Foundations of Finance)
